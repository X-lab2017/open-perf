# %%
import requests
import pandas as pd
# 设置GitHub访问令牌
access_token = ''
headers = {'Authorization': f'token {access_token}'}
repo_info = {
    "Repository Name": [],
}
# GitHub API URL
url = 'https://api.github.com/search/repositories'
for page in range(1, 11):
    # 设置搜索参数（按星标数量排序）
    params = {
        'q': 'stars:<476',  # 选择星标超过1000的仓库
        'sort': 'stars',
        'order': 'desc',
        'per_page': 100,  # 每页结果数（最多100）
        'page': page  # 页码
    }
    
    # 发起GET请求
    response = requests.get(url, headers=headers, params=params)
    
    # 检查响应状态码
    if response.status_code == 200:
        data = response.json()
        repositories = data['items']
    
        # 打印热门仓库信息
        for repo in repositories:
            repo_info["Repository Name"].append(repo['full_name'])
            print(f"Name: {repo['full_name']}")
    else:
        print(f"Failed to fetch repositories: {response.status_code}")
        
# 将字典转换为 DataFrame
df = pd.DataFrame.from_dict(repo_info, orient='index').transpose()

# 将 DataFrame 保存为 CSV 文件
df.to_csv('repo_name10.csv', index=False)
# Out:
# Name: wycats/moneta
# Name: mashaal/wild-cherry
# Name: clayallsopp/routable-android
# Name: jayrambhia/CropperNoCropper
# Name: robrix/RXCollections
# Name: horizon3ai/vcenter_saml_login
# Name: keymetrics/docker-pm2
# Name: tinystacks/precloud
# Name: dxxzst/OfflineMap
# Name: bryandlee/FreezeG
# Name: skydoves/ColorPickerPreference
# Name: oxc-project/javascript-parser-in-rust
# Name: nslogx/weapp-poem
# Name: grepplabs/kafka-proxy
# Name: forscht/ddrive
# Name: Kirilllive/tuesday-js
# Name: ibireme/YYDispatchQueuePool
# Name: allynbauer/statuspanic
# Name: nessos/LinqOptimizer
# Name: jonataslaw/get_server
# Name: alvyxaz/barebones-masterserver
# Name: nwutils/nw-updater
# Name: rashevskyv/kefir
# Name: wangdongdut/Online-Visual-Tracking-SOTA
# Name: XifengGuo/DEC-keras
# Name: Lyfhael/DeleteTweets
# Name: gucong3000/mirror-config-china
# Name: mcthesw/game-save-manager
# Name: egoist/vue-client-only
# Name: keremciu/font-bundles
# Name: bradfitz/embiggen-disk
# Name: hongyangAndroid/ColorfulStatusBar
# Name: lionsoul2014/friso
# Name: eclipse-archived/golo-lang
# Name: reidmorrison/symmetric-encryption
# Name: mustafaaljadery/lightning-whisper-mlx
# Name: matiasinsaurralde/go-dotnet
# Name: Beaver-Notes/Beaver-Notes
# Name: srg74/WLED-wemos-shield
# Name: DavidSheh/CommonChineseCharacter
# Name: Shopify/ruby-style-guide
# Name: skydoves/TheMovies2
# Name: werbhelius/GankWithZhihu
# Name: jnunemaker/fancy-zoom
# Name: ysbaddaden/prax
# Name: gaussic/SpringMVCDemo
# Name: chrisdone-archive/jl
# Name: bdebon/choiceof.dev
# Name: kronusme/dota2-api
# Name: Sephiroth87/Crayons
# Name: balsn/ctf_writeup
# Name: atatanasov/gijgo
# Name: czhen09/ESJsonFormatForMac
# Name: davidaurelio/TouchScroll
# Name: rsrbk/SRCountdownTimer
# Name: timdorr/spotifeed
# Name: sane/sane
# Name: balacode/one-file-pdf
# Name: vatro/svelthree
# Name: hallatore/stable-diffusion-webui-chatgpt-utilities
# Name: humanwhocodes/humanfs
# Name: alexcanessa/typescript-coverage-report
# Name: react-component/time-picker
# Name: emacsorphanage/quickrun
# Name: jacktuck/unfurl
# Name: icon11-community/Folder11
# Name: github/vscode-github-actions
# Name: WangWenBin2017/OpenWrt-SSRPLUS
# Name: koaning/bulk
# Name: duanhongyi/gmssl
# Name: milkdrop2077/MilkDrop3
# Name: zaeleus/noodles
# Name: kendo-labs/angular-kendo
# Name: timctho/VNect-tensorflow
# Name: infinit/elle
# Name: react-component/queue-anim
# Name: funcool/clojurescript-unraveled
# Name: fluttercommunity/flutter_after_layout
# Name: carbon-design-system/carbon-web-components
# Name: antoniosarosi/Wallpapers
# Name: chengstone/cchess-zero
# Name: twbs/examples
# Name: sumithemmadi/truecallerjs
# Name: Purple-Devs/health_check
# Name: mixpanel/mixpanel-node
# Name: apache/dubbo-go-pixiu
# Name: keijiro/FaceMeshBarracuda
# Name: spiral-modules/php-grpc
# Name: appbaseio/abc
# Name: hzy46/TensorFlow-Time-Series-Examples
# Name: BLINDED-AM-ME/UnityAssets
# Name: mercyblitz/mercyblitz.github.io
# Name: brave/brave-ui
# Name: qiniu/iconv
# Name: dome272/Instagram-DeepFake-Bot
# Name: lijiankun24/ShadowLayout
# Name: Grokmoo/sulis
# Name: spacemonkeygo/openssl
# Name: kulpreetchilana/Custom-iOS-Keyboards
# Name: sachinkesiraju/SKSplashView
# Name: humanwhocodes/humanfs
# Name: kendo-labs/angular-kendo
# Name: akanazawa/cmr
# Name: PerseveranceZ/vue-develop-template
# Name: bcrusco/Forward-Plus-Renderer
# Name: wsl2ls/WKWebView
# Name: troyzhxu/okhttps
# Name: wiidev/usbloadergx
# Name: jefflai108/Contrastive-Predictive-Coding-PyTorch
# Name: mwgg/Airports
# Name: quantsbin/Quantsbin
# Name: Reginer/aosp-android-jar
# Name: adminerevo/adminerevo
# Name: AndyObtiva/glimmer-dsl-libui
# Name: ArtiomTr/jest-coverage-report-action
# Name: nodejs/next-10
# Name: alialbaali/Noto
# Name: cloudfoundry/gosigar
# Name: timctho/VNect-tensorflow
# Name: infinit/elle
# Name: react-component/queue-anim
# Name: diederikdehaas/rtl8812AU
# Name: menyifang/ADGAN
# Name: microsoft/pxt-arcade
# Name: henghuiding/MeViS
# Name: instructor-ai/instructor-js
# Name: tomwechsler/Active_Directory_Advanced_Threat_Hunting
# Name: corpnewt/Hackintosh-Guide
# Name: JohnBra/vite-web-extension
# Name: chen-kai-1/meituan-shenquan
# Name: 3lp4tr0n/BeaconHunter
# Name: typst/packages
# Name: axe-api/axe-api
# Name: funcool/clojurescript-unraveled
# Name: fluttercommunity/flutter_after_layout
# Name: carbon-design-system/carbon-web-components
# Name: Purple-Devs/health_check
# Name: mixpanel/mixpanel-node
# Name: apache/dubbo-go-pixiu
# Name: keijiro/FaceMeshBarracuda
# Name: spiral-modules/php-grpc
# Name: appbaseio/abc
# Name: hzy46/TensorFlow-Time-Series-Examples
# Name: BLINDED-AM-ME/UnityAssets
# Name: mercyblitz/mercyblitz.github.io
# Name: Asabeneh/React-For-Everyone
# Name: afgprogrammer/Flutter-examples
# Name: chaos/pdsh
# Name: peachananr/panorama_viewer
# Name: gytis-ivaskevicius/flake-utils-plus
# Name: AvaloniaUI/avalonia-dotnet-templates
# Name: pauleve/docker-mtgo
# Name: kube-burner/kube-burner
# Name: Snawoot/hola-proxy
# Name: brave/brave-ui
# Name: qiniu/iconv
# Name: dome272/Instagram-DeepFake-Bot
# Name: lijiankun24/ShadowLayout
# Name: Grokmoo/sulis
# Name: spacemonkeygo/openssl
# Name: kulpreetchilana/Custom-iOS-Keyboards
# Name: DIYer22/boxx
# Name: jtsage/jtsage-datebox
# Name: arjo129/uSpeech
# Name: zaki/irrlicht
# Name: dfaker/df
# Name: 5e-bits/5e-srd-api
# Name: JunweiLiang/Object_Detection_Tracking
# Name: dfirtrack/dfirtrack
# Name: iamseth/oracledb_exporter
# Name: solid/specification
# Name: surajp92/CFD_Julia
# Name: rust-hosted-langs/book
# Name: satchelwu/QSS-Skin-Builder
# Name: 3ximus/aerial-sddm-theme
# Name: daeh/zotero-markdb-connect
# Name: sachinkesiraju/SKSplashView
# Name: Carbs0126/AvatarImageView
# Name: DenTelezhkin/ZoomInteractiveTransition
# Name: jeresig/node-stream-playground
# Name: dmsurti/AssimpKit
# Name: igorbrigadir/awesome-twitter-algo
# Name: google-deepmind/dsprites-dataset
# Name: psychic-api/doctran
# Name: lecepin/douyin-downloader
# Name: nyu-dl/dl4marco-bert
# Name: mervick/aes-everywhere
# Name: caserec/CaseRecommender
# Name: pfalcon/awesome-smarthome
# Name: miscreant/meta
# Name: tianyicui/DP-Book
# Name: changlan/kytan
# Name: webmozart/path-util
# Name: work7z/CodeGen
# Name: go-joe/joe
# Name: hong52ni/JavaAdvance-Interview
# Name: cydonia999/VGGFace2-pytorch
# Name: corenel/pytorch-adda
# Name: TeehanLax/UICollectionView-Spring-Demo
# Name: leanote/leanote-ios
# Name: ttezel/unio
# Name: iiunknown/iscroll5.doc.cn
# Name: mame82/duck2spark
# Name: ustbhuangyi/storage
# Name: dovpanda-dev/dovpanda
# Name: GunhoChoi/PyTorch-FastCampus
# Name: kevinohara80/nforce
# Name: joshbuddy/spoiler-alert
# Name: skydoves/Submarine
# Name: PoweredLocal/vrata
# Name: shuaiwang007/RAC
# Name: wchaowu/nodejs
# Name: nsonnad/base16-ipython-notebook
# Name: mukeshthawani/FAQView
# Name: nshaud/DeepNetsForEO
# Name: webrtc/testrtc
# Name: larspars/word-rnn
# Name: offensive-security/masscan-web-ui
# Name: fireship-io/next-firebase-course
# Name: tabwrangler/tabwrangler
# Name: GoogleCloudPlatform/practical-ml-vision-book
# Name: Twixes/SF-Mono-Powerline
# Name: DedalusProject/dedalus
# Name: node-red/node-red-docker
# Name: Cc28256/CcRemote
# Name: pubpub/pubpub
# Name: mistralai/mistral-common
# Name: natethinks/jog
# Name: saberma/china_sms
# Name: cpjk/canary
# Name: steemit/steem-js
# Name: sihorton/appjs-deskshell
# Name: rs/SafariTabSwitching
# Name: CyanogenMod/android_packages_apps_Trebuchet
# Name: tranleduy2000/javaide
# Name: keijiro/SkeletalGeometricEffects
# Name: dlsys-course/assignment1-2018
# Name: codenamecpp/carnage3d
# Name: reactphp/dns
# Name: ros-controls/ros_control
# Name: szw/vim-maximizer
# Name: crigler/dtach
# Name: fashare2015/StackLayout
# Name: facebookresearch/one_shot_3d_photography
# Name: nix-dot-dev/getting-started-devenv-template
# Name: microsoft/HoloLensForCV
# Name: NVIDIA/MDL-SDK
# Name: JuliaPy/PyPlot.jl
# Name: rtrouton/create_macos_vm_install_dmg
# Name: amitds1997/remote-nvim.nvim
# Name: tobami/littlechef
# Name: ricsinaruto/Seq2seqChatbots
# Name: vczh/gac
# Name: JingYeoh/VercodeEditText
# Name: nbartlomiej/foggy
# Name: danielegrattarola/keras-gat
# Name: mhlzr/html5-videoEditor
# Name: HillZhang1999/MuCGEC
# Name: chenkui164/FastASR
# Name: greggagne/osc10e
# Name: gregertw/actingweb_firstapp
# Name: The-Viper-One/Pentest-Everything
# Name: espressif/ESP8266_AT
# Name: enobufs/stun
# Name: feicong/sec_skills
# Name: massoudss/waveformSeekBar
# Name: ma-xu/pointMLP-pytorch
# Name: eraser-dev/eraser
# Name: JohnSnowLabs/langtest
# Name: tkahn/Smooth-Div-Scroll
# Name: EasyCorp/easy-deploy-bundle
# Name: v2018z/xueXiQiangguo
# Name: Alpha-VL/ConvMAE
# Name: appy-one/acebase
# Name: lewster32/phaser-plugin-isometric
# Name: GLSL-Debugger/GLSL-Debugger
# Name: hanks-zyh/AnimateCheckBox
# Name: mistamek/Android-drawable-preview-plugin
# Name: sergeywong/cp-vton
# Name: mikeal/merge-release
# Name: mathiasbynens/jsperf.com
# Name: jprante/elasticsearch-knapsack
# Name: draftcode/ijaas
# Name: adhamenaya/AndroidMosaicLayout
# Name: salesforce/cove
# Name: timsayshey/Ghost-Markdown-Editor
# Name: pengjianbo/FloatViewFinal
# Name: nicejade/vue-boilerplate-template
# Name: jiecaoyu/XNOR-Net-PyTorch
# Name: nknorg/nkn
# Name: AbdurRKhalid/Design-Patterns
# Name: reactjs/pt-br.react.dev
# Name: makedeb/makedeb
# Name: benawad/jwt-auth-example
# Name: benblack86/linkclump
# Name: termux/termux-docker
# Name: Mq-b/Modern-Cpp-templates-tutorial
# Name: gracicot/kangaru
# Name: malcommac/UIWindowTransitions
# Name: yingLanNull/CircleAlarmTimerView
# Name: jtleek/readingpapers
# Name: mpoeter/xenium
# Name: winget-run/wingetdotrun
# Name: Boris-Em/BEMAnalogClock
# Name: Voyzz/Fruit-store-mp
# Name: radix-svelte/radix-svelte
# Name: lhz960904/movie-trailer
# Name: microsoft/ClimaX
# Name: milaan9/93_Python_Data_Analytics_Projects
# Name: yl4579/StarGANv2-VC
# Name: filecoin-project/community
# Name: PX4/PX4-ECL
# Name: ultrasecurity/DarkSide
# Name: chanind/hanzi-writer-data
# Name: yjs/y-websocket
# Name: Zielon/PBRVulkan
# Name: Anuken/MindustryBuilds
# Name: stroebjo/autohotkey-windows-mac-keyboard
# Name: laylacodes/cheatsheets
# Name: mukeshthawani/FAQView
# Name: nshaud/DeepNetsForEO
# Name: webrtc/testrtc
# Name: larspars/word-rnn
# Name: offensive-security/masscan-web-ui
# Name: fireship-io/next-firebase-course
# Name: tabwrangler/tabwrangler
# Name: GoogleCloudPlatform/practical-ml-vision-book
# Name: Twixes/SF-Mono-Powerline
# Name: DedalusProject/dedalus
# Name: node-red/node-red-docker
# Name: Cc28256/CcRemote
# Name: pubpub/pubpub
# Name: mistralai/mistral-common
# Name: nmn/react-infinity
# Name: thepanacealab/covid19_twitter
# Name: soffes/SyntaxKit
# Name: artetxem/undreamt
# Name: sihorton/appjs-deskshell
# Name: rs/SafariTabSwitching
# Name: CyanogenMod/android_packages_apps_Trebuchet
# Name: tranleduy2000/javaide
# Name: keijiro/SkeletalGeometricEffects
# Name: dlsys-course/assignment1-2018
# Name: codenamecpp/carnage3d
# Name: reactphp/dns
# Name: ros-controls/ros_control
# Name: szw/vim-maximizer
# Name: crigler/dtach
# Name: tobami/littlechef
# Name: ricsinaruto/Seq2seqChatbots
# Name: muccc/iridium-toolkit
# Name: akon47/ScreenRecorder
# Name: vczh/gac
# Name: JingYeoh/VercodeEditText
# Name: nbartlomiej/foggy
# Name: danielegrattarola/keras-gat
# Name: mhlzr/html5-videoEditor
# Name: HillZhang1999/MuCGEC
# Name: chenkui164/FastASR
# Name: greggagne/osc10e
# Name: gregertw/actingweb_firstapp
# Name: The-Viper-One/Pentest-Everything
# Name: PrithivirajDamodaran/Styleformer
# Name: CSS-Tricks/serverless
# Name: hackstoic/kubernetes_practice
# Name: fals/cqrs-clean-eventual-consistency
# Name: quatanium/python-onvif
# Name: lotabout/Let-s-build-a-compiler
# Name: tkahn/Smooth-Div-Scroll
# Name: EasyCorp/easy-deploy-bundle
# Name: v2018z/xueXiQiangguo
# Name: Alpha-VL/ConvMAE
# Name: appy-one/acebase
# Name: lewster32/phaser-plugin-isometric
# Name: mistamek/Android-drawable-preview-plugin
# Name: sergeywong/cp-vton
# Name: mikeal/merge-release
# Name: gael-ian/vagrant-bindfs
# Name: iotaledger/trinity-wallet
# Name: igrigorik/bloomfilter-rb
# Name: getkirby-v2/kirby
# Name: dherman/defense-of-dot-js
# Name: satcar77/miband4
# Name: christopherpow/nes-test-roms
# Name: Ulydev/push
# Name: PacktPublishing/Modern-CMake-for-Cpp
# Name: miranda-ng/miranda-ng
# Name: wu-hao-ze/All-assignments-and-projects-for-software-engineering-courses-at-Tongji-University
# Name: Stardust-kyun/dotfiles
# Name: peteanderson80/Matterport3DSimulator
# Name: Automattic/developer
# Name: skx/tunneller
# Name: mattrighetti/envelope
# Name: brunomikoski/ScriptableObjectCollection
# Name: mathiasbynens/jsperf.com
# Name: Nirma/Default
# Name: conceptdev/xamarin-forms-samples
# Name: GoogleCloudPlatform/covid-19-open-data
# Name: RisingStack/trace-nodejs
# Name: simplesteph/grpc-go-course
# Failed to fetch repositories: 403
# Failed to fetch repositories: 403
# Failed to fetch repositories: 403
# Failed to fetch repositories: 403
# Failed to fetch repositories: 403
# Failed to fetch repositories: 403

# %%
from github import Github
import pandas as pd

# 用你的 GitHub 访问令牌替换
ACCESS_TOKEN = ''

# 初始化 Github 客户端
g = Github(ACCESS_TOKEN)

# 替换为你想要获取信息的仓库名称列表
df = pd.read_csv('repo_name10.csv')
REPO_LIST = df['Repository Name'].tolist()

# 创建一个列表存储所有仓库的信息
repo_data = []

# 获取仓库描述
def get_repo_description(repo):
    return repo.description

# 获取代码内容
def get_repo_contents(repo, path=""):
    contents = repo.get_contents(path)
    code_contents = []
    while contents:
        file_content = contents.pop(0)
        if file_content.type == "dir":
            contents.extend(repo.get_contents(file_content.path))
        else:
            code_contents.append(f"File: {file_content.path}")
    return "\n".join(code_contents)

# 获取前5条提交历史
def get_commit_history(repo, limit=3):
    commits = repo.get_commits()[:limit]
    commit_history = []
    for commit in commits:
        commit_history.append(f"Author: {commit.commit.author.name}")
        commit_history.append(f"Date: {commit.commit.author.date}")
        commit_history.append(f"Message: {commit.commit.message}")
    return "\n".join(commit_history)

# 获取README文件
def get_readme(repo):
    try:
        readme = repo.get_readme()
        return readme.decoded_content.decode()
    except:
        return "No README found"

# 获取5条标签信息
def get_tags(repo):
    tags = repo.get_tags()
    if tags.totalCount == 0:
        return "No tags found"
    tag=tags[0]
    tag_info = []
    tag_info.append(f"Tag: {tag.name}")
    try:
        tag_ref = repo.get_git_tag(tag.commit.sha)
        tag_info.append(f"Message: {tag_ref.message}")
        tag_info.append(f"Tagger: {tag_ref.tagger.name}")
        tag_info.append(f"Date: {tag_ref.tagger.date}")
    except:
        tag_info.append("No additional tag information")
    return "\n".join(tag_info)

# 获取标签信息
def get_topics(repo):
    if repo.get_topics():
        return repo.get_topics()[0:10]
    else :
        return 'No topics'

# 处理每个仓库
for repo_name in REPO_LIST:
    print(f"begin getting {repo_name}")
    repo = g.get_repo(repo_name)
    repo_info = {
        "Repository Name": repo_name,
        "Description": get_repo_description(repo),
        "Code Content": get_repo_contents(repo),
        "Commit History": get_commit_history(repo),
        "README Content": get_readme(repo),
        "Tags": get_tags(repo),
        "Topics": get_topics(repo)
    }
    # repo_data.append(repo_info)
    # 将数据转换为 DataFrame
    
    new_data_list = {key: [value] for key, value in repo_info.items()}
    df = pd.DataFrame(new_data_list)
    df.to_csv('repos_info.csv', mode='a', header=False, index=False)

print("Information saved to repos_info.csv")
# Out:
# begin getting wycats/moneta
# begin getting mashaal/wild-cherry
# begin getting clayallsopp/routable-android
# begin getting jayrambhia/CropperNoCropper
# begin getting robrix/RXCollections
# begin getting horizon3ai/vcenter_saml_login
# begin getting keymetrics/docker-pm2
# begin getting tinystacks/precloud
# begin getting dxxzst/OfflineMap
# begin getting bryandlee/FreezeG
# begin getting skydoves/ColorPickerPreference
# begin getting oxc-project/javascript-parser-in-rust
# begin getting nslogx/weapp-poem
# begin getting grepplabs/kafka-proxy
# begin getting forscht/ddrive
# begin getting Kirilllive/tuesday-js
# begin getting ibireme/YYDispatchQueuePool
# begin getting allynbauer/statuspanic
# begin getting nessos/LinqOptimizer
# begin getting jonataslaw/get_server
# begin getting alvyxaz/barebones-masterserver
# begin getting nwutils/nw-updater
# begin getting rashevskyv/kefir
# begin getting wangdongdut/Online-Visual-Tracking-SOTA
# begin getting XifengGuo/DEC-keras
# begin getting Lyfhael/DeleteTweets
# begin getting gucong3000/mirror-config-china
# begin getting mcthesw/game-save-manager
# begin getting egoist/vue-client-only
# begin getting keremciu/font-bundles
# begin getting bradfitz/embiggen-disk
# begin getting hongyangAndroid/ColorfulStatusBar
# begin getting lionsoul2014/friso
# begin getting eclipse-archived/golo-lang
# begin getting reidmorrison/symmetric-encryption
# begin getting mustafaaljadery/lightning-whisper-mlx
# begin getting matiasinsaurralde/go-dotnet
# begin getting Beaver-Notes/Beaver-Notes
# begin getting srg74/WLED-wemos-shield
# begin getting DavidSheh/CommonChineseCharacter
# begin getting Shopify/ruby-style-guide
# begin getting skydoves/TheMovies2
# begin getting werbhelius/GankWithZhihu
# begin getting jnunemaker/fancy-zoom
# begin getting ysbaddaden/prax
# begin getting gaussic/SpringMVCDemo
# begin getting chrisdone-archive/jl
# begin getting bdebon/choiceof.dev
# begin getting kronusme/dota2-api
# begin getting Sephiroth87/Crayons
# begin getting balsn/ctf_writeup
# begin getting atatanasov/gijgo
# begin getting czhen09/ESJsonFormatForMac
# begin getting davidaurelio/TouchScroll
# begin getting rsrbk/SRCountdownTimer
# begin getting timdorr/spotifeed
# begin getting sane/sane
# begin getting balacode/one-file-pdf
# begin getting vatro/svelthree
# begin getting hallatore/stable-diffusion-webui-chatgpt-utilities
# begin getting humanwhocodes/humanfs
# begin getting alexcanessa/typescript-coverage-report
# begin getting react-component/time-picker
# begin getting emacsorphanage/quickrun
# begin getting jacktuck/unfurl
# begin getting icon11-community/Folder11
# begin getting github/vscode-github-actions
# begin getting WangWenBin2017/OpenWrt-SSRPLUS
# begin getting koaning/bulk
# begin getting duanhongyi/gmssl
# begin getting milkdrop2077/MilkDrop3
# begin getting zaeleus/noodles
# begin getting kendo-labs/angular-kendo
# begin getting timctho/VNect-tensorflow
# begin getting infinit/elle
# begin getting react-component/queue-anim
# begin getting funcool/clojurescript-unraveled
# begin getting fluttercommunity/flutter_after_layout
# begin getting carbon-design-system/carbon-web-components
# begin getting antoniosarosi/Wallpapers
# begin getting chengstone/cchess-zero
# begin getting twbs/examples
# begin getting sumithemmadi/truecallerjs
# begin getting Purple-Devs/health_check
# begin getting mixpanel/mixpanel-node
# begin getting apache/dubbo-go-pixiu
# begin getting keijiro/FaceMeshBarracuda
# begin getting spiral-modules/php-grpc
# begin getting appbaseio/abc
# begin getting hzy46/TensorFlow-Time-Series-Examples
# begin getting BLINDED-AM-ME/UnityAssets
# begin getting mercyblitz/mercyblitz.github.io
# begin getting brave/brave-ui
# begin getting qiniu/iconv
# begin getting dome272/Instagram-DeepFake-Bot
# begin getting lijiankun24/ShadowLayout
# begin getting Grokmoo/sulis
# Request GET /repos/Grokmoo/sulis/contents/data/sounds/sfx/sfx_100 failed with 403: Forbidden
# Setting next backoff to 94.212673s
# begin getting spacemonkeygo/openssl
# begin getting kulpreetchilana/Custom-iOS-Keyboards
# begin getting sachinkesiraju/SKSplashView
# begin getting humanwhocodes/humanfs
# begin getting kendo-labs/angular-kendo
# begin getting akanazawa/cmr
# begin getting PerseveranceZ/vue-develop-template
# begin getting bcrusco/Forward-Plus-Renderer
# begin getting wsl2ls/WKWebView
# begin getting troyzhxu/okhttps
# begin getting wiidev/usbloadergx
# begin getting jefflai108/Contrastive-Predictive-Coding-PyTorch
# begin getting mwgg/Airports
# begin getting quantsbin/Quantsbin
# begin getting Reginer/aosp-android-jar
# Request GET /repos/Reginer/aosp-android-jar/contents/android-32/src/com/android/server/display/whitebalance failed with 403: Forbidden
# Setting next backoff to 220.550838s

# %%
import pandas as pd
df = pd.read_csv('repo_allbut1.csv')
REPO_LIST = df['Repository Name'].tolist()

# %%
REPO_LIST
# Out:
# ['hiroi-sora/Umi-OCR',
#  'MostlyAdequate/mostly-adequate-guide',
#  'StreisandEffect/streisand',
#  'youzan/vant',
#  'gfwlist/gfwlist',
#  'electron-react-boilerplate/electron-react-boilerplate',
#  'kovidgoyal/kitty',
#  'gocolly/colly',
#  'responsively-org/responsively-app',
#  'HeroTransitions/Hero',
#  'Swordfish90/cool-retro-term',
#  'opentofu/opentofu',
#  'dylanaraps/neofetch',
#  'pugjs/pug',
#  'dandavison/delta',
#  'julycoding/The-Art-Of-Programming-By-July-2nd',
#  'typicode/lowdb',
#  'ColorlibHQ/gentelella',
#  'duckdb/duckdb',
#  'pubkey/rxdb',
#  'FelisCatus/SwitchyOmega',
#  'emilk/egui',
#  'JohnCoates/Aerial',
#  'ajeetdsouza/zoxide',
#  'petkaantonov/bluebird',
#  'keepassxreboot/keepassxc',
#  'graphql/graphql-js',
#  'Bin-Huang/chatbox',
#  'ungoogled-software/ungoogled-chromium',
#  'SBoudrias/Inquirer.js',
#  'zellij-org/zellij',
#  'facebookarchive/pop',
#  'thangchung/awesome-dotnet-core',
#  'karpathy/minGPT',
#  'timqian/chinese-independent-blogs',
#  'vueuse/vueuse',
#  'tobiasahlin/SpinKit',
#  'wekan/wekan',
#  'airbnb/visx',
#  'knex/knex',
#  'slimtoolkit/slim',
#  'simdjson/simdjson',
#  'scottbez1/smartknob',
#  'jcjohnson/neural-style',
#  'wasmerio/wasmer',
#  'mysqljs/mysql',
#  'RustPython/RustPython',
#  'SnapKit/Masonry',
#  'SigNoz/signoz',
#  'vim-airline/vim-airline',
#  'crewAIInc/crewAI',
#  'wangeditor-team/wangEditor',
#  'LMAX-Exchange/disruptor',
#  'nvim-lua/kickstart.nvim',
#  'vectordotdev/vector',
#  'lxgw/LxgwWenKai',
#  'wilsonfreitas/awesome-quant',
#  'reddit-archive/reddit',
#  'browsh-org/browsh',
#  'plotly/plotly.js',
#  'gleam-lang/gleam',
#  'lottie-react-native/lottie-react-native',
#  'air-verse/air',
#  'alsotang/node-lessons',
#  'Mikubill/sd-webui-controlnet',
#  'briannesbitt/Carbon',
#  'ether/etherpad-lite',
#  'terrastruct/d2',
#  'go-playground/validator',
#  'MarlinFirmware/Marlin',
#  'android/nowinandroid',
#  'jmoiron/sqlx',
#  'thunlp/GNNPapers',
#  'altercation/solarized',
#  'umijs/qiankun',
#  'spf13/spf13-vim',
#  'uber-go/guide',
#  'bvaughn/react-window',
#  'meta-llama/codellama',
#  'OptimalBits/bull',
#  'InterviewReady/system-design-resources',
#  'whyour/qinglong',
#  'greyireland/algorithm-pattern',
#  'RealKai42/qwerty-learner',
#  'kailashahirwar/cheatsheets-ai',
#  'cmusatyalab/openface',
#  'microsoft/IoT-For-Beginners',
#  'sass/sass',
#  'airbnb/react-sketchapp',
#  'automerge/automerge-classic',
#  'microsoft/Bringing-Old-Photos-Back-to-Life',
#  'deepset-ai/haystack',
#  'rust-lang/book',
#  'TGSAN/CMWTAT_Digital_Edition',
#  'hapijs/hapi',
#  'Konloch/bytecode-viewer',
#  'PavelDoGreat/WebGL-Fluid-Simulation',
#  'rocksdanister/lively',
#  'apple/foundationdb',
#  'Infisical/infisical',
#  'acidanthera/OpenCorePkg',
#  'philipwalton/solved-by-flexbox',
#  'LemmyNet/lemmy',
#  'google-deepmind/deepmind-research',
#  'edgedb/edgedb',
#  'scipy/scipy',
#  'AI4Finance-Foundation/FinGPT',
#  'greenrobot/greenDAO',
#  'postmanlabs/httpbin',
#  'tmuxinator/tmuxinator',
#  'SFTtech/openage',
#  'google/guice',
#  'Automattic/wp-calypso',
#  'twpayne/chezmoi',
#  'mwaskom/seaborn',
#  'ttroy50/cmake-examples',
#  'PrismJS/prism',
#  'jedisct1/libsodium',
#  'humiaozuzu/awesome-flask',
#  'Chalarangelo/30-seconds-of-interviews',
#  'haiwen/seafile',
#  'langchain-ai/langchainjs',
#  'slimphp/Slim',
#  'rougier/numpy-100',
#  'matrix-org/synapse',
#  'Embedding/Chinese-Word-Vectors',
#  'peng-zhihui/Dummy-Robot',
#  'Matt-Esch/virtual-dom',
#  'Unity-Technologies/UnityCsReference',
#  'ansible/ansible-examples',
#  'barbajs/barba',
#  'ionic-team/capacitor',
#  'frank-lam/fullstack-tutorial',
#  'summernote/summernote',
#  'Nuitka/Nuitka',
#  'MatsuriDayo/nekoray',
#  'careercup/CtCI-6th-Edition',
#  'p8952/bocker',
#  'mzlogin/awesome-adb',
#  'girliemac/a-picture-is-worth-a-1000-words',
#  'cjwirth/awesome-ios-ui',
#  'jordansissel/fpm',
#  'rust-lang/rust-clippy',
#  'doctrine/lexer',
#  'ludwig-ai/ludwig',
#  'Pawdroid/Free-servers',
#  'TodePond/DreamBerd',
#  'shuding/nextra',
#  'lengstrom/fast-style-transfer',
#  'hackstoic/golang-open-source-projects',
#  'future-architect/vuls',
#  'magicalpanda/MagicalRecord',
#  'liu673cn/bug',
#  'mas-cli/mas',
#  'aristocratos/bashtop',
#  'rushter/MLAlgorithms',
#  'systemdesign42/system-design',
#  'infracost/infracost',
#  'JamesNK/Newtonsoft.Json',
#  'shiburagi/Drawer-Behavior',
#  'tastejs/PropertyCross',
#  'laihuamin/JS-total',
#  'little2s/NoChat',
#  'jeasonlzy/PullZoomView',
#  'steveruizok/perfect-cursors',
#  'hseeberger/akka-http-json',
#  'reinder42/SwiftCheatsheet',
#  'mcedit/mcedit',
#  'python-needle/needle',
#  'chrislloyd/gravtastic',
#  'castorini/hedwig',
#  'commonsguy/cwac-merge',
#  'kaleai/ActivityOptionsICS',
#  'FrontEndRoad/HTML5-FAQ',
#  'JadenZhong/wechat-flutter',
#  'JacksonWuxs/DaPy',
#  'shaojiankui/ProfilesManager',
#  'hx173149/C3D-tensorflow',
#  'twitter-archive/twitter-text-objc',
#  'threedaymonk/text',
#  'kangshaojun/flutter-book',
#  'ole/OLEContainerScrollView',
#  'TMRh20/TMRpcm',
#  'crysislinux/chrome-react-perf',
#  'kriswallsmith/spork',
#  'Jpadilla1/react-native-ios-charts',
#  'ssola/python-flask-microservice',
#  'saabi/vminpoly',
#  'geowarin/boot-react',
#  'Lattyware/unrpa',
#  'ekmartin/slack-irc',
#  'senny/emacs-eclim',
#  'abarisain/dmix',
#  'chrisvfritz/7-secret-patterns',
#  'genemu/GenemuFormBundle',
#  'yangxu4536/MeiTuanLocateCity',
#  'zorkian/nagios-api',
#  'tjfontaine/node-dns',
#  'tomkrcha/drawscript',
#  'infinitest/infinitest',
#  'cthorey/CS231',
#  'sromku/memory-game',
#  'ryanmaxwell/UncrustifyX',
#  'donobono/DoImagePickerController',
#  'marload/DeepRL-TensorFlow2',
#  'deckarep/gosx-notifier',
#  'rodionovd/SWRoute',
#  'FahimF/SQLiteDB',
#  'szagoruyko/diracnets',
#  'Almighty-Alpaca/JetBrains-Discord-Integration',
#  'tenntenn/gopher-stickers',
#  'vestrel00/contacts-android',
#  'docker/libcompose',
#  'joshwcomeau/redux-vcr',
#  'nullobject/fkit',
#  'philipwalton/responsive-components',
#  'maxmx/bootstrap-stylus',
#  'pragmaticly/smart-time-ago',
#  'LinkedInAttic/datafu',
#  'stomita/ios-imagefile-megapixel',
#  'moonshawdo/checkgoogleip',
#  'yannickl/Reactions',
#  'daemon3000/InputManager',
#  'jojozhai/security',
#  'neolee/pilot',
#  'OiPunk/OnlineTaxi',
#  'beyondcode/laravel-credentials',
#  'graphql-compose/graphql-compose-elasticsearch',
#  'davidgohel/officer',
#  'remirobert/CameraEngine',
#  'arthur-e/Wicket',
#  'Xilinx/u-boot-xlnx',
#  'astro/gitpop',
#  'ck86/main-bower-files',
#  'CoderJackyHuang/HYBNetworking',
#  'calvinmetcalf/catiline',
#  'noveogroup/backbone.iobind',
#  'firebreath/FireBreath',
#  'TooTallNate/ansi-canvas',
#  'alejandro-ao/langchain-ask-pdf',
#  'utsuboco/r3f-perf',
#  'jenzz/Android-UndoBar',
#  'notofonts/noto-source',
#  'hornhuang/android_interviews',
#  'bguerout/jongo',
#  'joelmoss/strano',
#  'daniellmb/JavaScript-Scope-Context-Coloring',
#  'alibaba/esim-response-selection',
#  'manjula-dube/react-advanced-patterns',
#  'JasonBai007/vue-seed',
#  'vigetlabs/Twitter-Bootstrap-for-Omnigraffle',
#  'ldiqual/tesseract-ios',
#  'kristopolous/TickTick',
#  'lasso-js/lasso',
#  'Yelp/yelp-api',
#  'keen/keen-js',
#  'noelportugal/google-home-notifier',
#  'cocagne/paxos',
#  'chris104957/maildown',
#  'dkwingsmt/haha',
#  'AtomLinter/linter-eslint',
#  'szagoruyko/functional-zoo',
#  'docker/libcompose',
#  'joshwcomeau/redux-vcr',
#  'linkedin/pygradle',
#  'drewr/postal',
#  'nullobject/fkit',
#  'ledokku/ledokku',
#  'rubyjs/mini_racer',
#  'tenderlove/rails_autolink',
#  'maxmx/bootstrap-stylus',
#  'pragmaticly/smart-time-ago',
#  'LinkedInAttic/datafu',
#  'stomita/ios-imagefile-megapixel',
#  'udacity/ud862-samples',
#  'speed/newcrawler',
#  'soyking/e3w',
#  'openenergymonitor/EmonLib',
#  'squeryl/squeryl',
#  'nstrayer/datadrivencv',
#  'github/maven-plugins',
#  'ming1016/STMURLCache',
#  'lorensiuswlt/NewQuickAction',
#  'paddybyers/anode',
#  'neolee/pilot',
#  'OiPunk/OnlineTaxi',
#  'beyondcode/laravel-credentials',
#  'nwojke/cosine_metric_learning',
#  'yoyofx/yoyogo',
#  'BetterJS/doc',
#  'devopsbookmarks/devopsbookmarks.com',
#  'graphql-compose/graphql-compose-elasticsearch',
#  'davidgohel/officer',
#  'flouthoc/calc.asm',
#  'gradiuscypher/infosec_getting_started',
#  'Kofktu/KUIPopOver',
#  'remirobert/CameraEngine',
#  'ant-design/create-react-app-antd',
#  'mrdoob/htmleditor',
#  'EasyTuan/mui-kidApp',
#  'signalapp/libsignal-service-java',
#  'timeglass/glass',
#  'bradfitz/exp-httpclient',
#  'jtriley/StarCluster',
#  'PKRoma/ProcessHacker',
#  'nforest/awesome-decompilation',
#  'jankais3r/LLaMA_MPS',
#  'huacnlee/social-share-button',
#  'fxia22/stn.pytorch',
#  'noveogroup/backbone.iobind',
#  'firebreath/FireBreath',
#  'codebrainz/geany-themes',
#  'alstr/todo-to-issue-action',
#  'cacheflowe/creative-coding-notes',
#  'motion-planning/rrt-algorithms',
#  'utsuboco/r3f-perf',
#  'ucbdrive/bdd100k',
#  'jenzz/Android-UndoBar',
#  'notofonts/noto-source',
#  'GFNOrg/gflownet',
#  'hornhuang/android_interviews',
#  'bguerout/jongo',
#  'joelmoss/strano',
#  'avinassh/grpc-errors',
#  'alphaSeclab/sec-tool-list',
#  'sxyazi/free-hls',
#  'daniellmb/JavaScript-Scope-Context-Coloring',
#  'timothycrosley/jiphy',
#  'JasonBai007/vue-seed',
#  'vigetlabs/Twitter-Bootstrap-for-Omnigraffle',
#  'kristopolous/TickTick',
#  'ifitdoesntwork/DAExpandAnimation',
#  'lasso-js/lasso',
#  'cbschuld/Browser.php',
#  'emersion/xdg-desktop-portal-wlr',
#  'LuciferHuang/heimdallr-sdk',
#  'Yelp/yelp-api',
#  'keen/keen-js',
#  'noelportugal/google-home-notifier',
#  'ampproject/amp.dev',
#  'dappuniversity/nft',
#  'togayther/react-native-cnblogs',
#  'emacs-php/php-mode',
#  'adidas/adidas-devops-maturity-framework',
#  'staticallyio/statically',
#  'xsank/webssh',
#  'google/palette.js',
#  'matthewmueller/socrates',
#  'comex/substitute',
#  'chiemy/CardView',
#  'ethereum-optimism/cannon',
#  'darsain/fpsmeter',
#  'angular-ui/ui-ace',
#  'josephmisiti/generic-django-project',
#  'ai/audio-recorder-polyfill',
#  'OpnTec/thai.opentech.asia',
#  'bfirsh/jsnes-web',
#  'javaee/javamail',
#  'aave/flashloan-box',
#  'weishen250/npscrack',
#  'bobbyiliev/introduction-to-git-and-github-ebook',
#  'inverse-scaling/prize',
#  'in28minutes/java-cheat-sheet',
#  'gavin66/proxy_list',
#  'resir014/react-redux-typescript-example',
#  'hkociemba/RubiksCube-TwophaseSolver',
#  'google/cctz',
#  'yuhua-chen/MCLog',
#  'tenntenn/gopher-stickers',
#  'vestrel00/contacts-android',
#  'jariz/MaterialUp',
#  'ericsomdahl/python-bittrex',
#  'kimmelsg/cj-upload',
#  'PaNaVTEC/DrawableView',
#  'javasmall/bigsai-algorithm',
#  'BrianSidebotham/arm-tutorial-rpi',
#  'aashrafh/Mozart',
#  'tailwindcomponents/dashboard',
#  'opencomputeproject/onie',
#  'davidpdrsn/todo-or-die',
#  'iMoonLab/DeepHypergraph',
#  'docker/libcompose',
#  'tenderlove/rails_autolink',
#  'twisted/treq',
#  'WICG/scroll-to-text-fragment',
#  'vinipsmaker/tufao',
#  'samarth-p/College-ERP',
#  'dropbox/dropbox-sdk-java',
#  'vermont42/Podcasts',
#  'orhanobut/wasp',
#  'Dewera/Lunar',
#  'cwilso/midi-synth',
#  'smsohan/MvcMailer',
#  'jxnblk/ram',
#  'Spreadsheets/WickedGrid',
#  'ryan-roemer/sphinx-bootstrap-theme',
#  'madongqiang2201/views',
#  'picoruby/picoruby',
#  'zju3dv/EasyVolcap',
#  'orwagodfather/WordList',
#  'PKM-er/media-extended',
#  'EalenXie/spring-microservice-ddd',
#  'RoboStack/jupyter-ros',
#  'go-share-team/go_interview',
#  'FluxML/FastAI.jl',
#  'nstevens/androidguide',
#  'dpnishant/jsprime',
#  'AlexChesser/recruiter-autoresponse',
#  'aws-samples/lambda-refarch-mobilebackend',
#  'maxmx/bootstrap-stylus',
#  'stomita/ios-imagefile-megapixel',
#  'alekseyn/EasyTableView',
#  'cvkki/src',
#  'melisgl/mgl',
#  'hjkl01/pornhub',
#  'swyxio/devtools-angels',
#  'google-developer-training/pwa-training-labs',
#  '6eer/uniswap-sushiswap-arbitrage-bot',
#  'aws/aws-sdk-rails',
#  'github/maven-plugins',
#  'ming1016/STMURLCache',
#  'lorensiuswlt/NewQuickAction',
#  'paddybyers/anode',
#  'challenger-deep-theme/vim',
#  'ANSSI-FR/rust-guide',
#  'google/u2f-ref-code',
#  'LoupVaillant/Monocypher',
#  'mdozmorov/scRNA-seq_notes',
#  'Boddlnagg/midir',
#  'JuliaRegistries/General',
#  'moonshawdo/checkgoogleip',
#  'yannickl/Reactions',
#  'daemon3000/InputManager',
#  'rollin0-0/DiffHelper',
#  'MahdiMashrur/Awesome-Application-Security-Checklist',
#  'PreOS-Security/awesome-firmware-security',
#  'TTimo/GtkRadiant',
#  'ThePrimeagen/htmx-lsp',
#  'yangshun/top-javascript-interview-questions',
#  'xmuSistone/android-snake-menu',
#  'katef/kgt',
#  'google/easypki',
#  'jqr/heroku_san',
#  'neolee/pilot',
#  'OiPunk/OnlineTaxi',
#  'beyondcode/laravel-credentials',
#  'supersheep/wechat-pay',
#  'StreetVoice/HysteriaPlayer',
#  'HenrikJoreteg/redux-bundler',
#  'bdarnell/torndb',
#  'domenic/svg2png',
#  'tumobi/nideshop-admin',
#  'Sjj1024/douyin-live',
#  'chubin/cheat.sheets',
#  'abhishekkrthakur/diffuzers',
#  'EasyTuan/mui-kidApp',
#  'signalapp/libsignal-service-java',
#  'timeglass/glass',
#  'bradfitz/exp-httpclient',
#  'TheNewNormal/kube-solo-osx',
#  'mozilla/moz-sql-parser',
#  'teambition/then.js',
#  'iatek/bootstrap-zero',
#  'iamshaunjp/typescript-tutorial',
#  'songdejia/EAST',
#  'glomadrian/dashed-circular-progress',
#  'ffffffff0x/Pentest101',
#  'asafdav/ng-csv',
#  'htmlx-org/HTMLx',
#  'l3uddz/traktarr',
#  'dotnetcore/SmartCode',
#  'threedr3am/ZhouYu',
#  'APIDevTools/swagger-express-middleware',
#  'twitter/ios-twitter-network-layer',
#  'soarcn/UndoBar',
#  'vaneenige/unswitch',
#  'sciyoshi/pyfacebook',
#  'jaubourg/jquery-jsonp',
#  'TryGOTry/DogCs4.4',
#  'Mamboleoo/DecorativeBackgrounds',
#  'luozhaohui/books',
#  'alibaba/Pai-Megatron-Patch',
#  'jerry1993-tech/Cornucopia-LLaMA-Fin-Chinese',
#  'dazinovic/neural-rgbd-surface-reconstruction',
#  'shprink/ionic-native-transitions',
#  'MattSurabian/DuckHunt-JS',
#  'libsm64/libsm64-blender',
#  'Kevin-De-Koninck/Get-It',
#  'phenomnomnominal/betterer',
#  'cloudflare/react-gateway',
#  'komljen/dockerfile-examples',
#  'Bitwise-01/Loki',
#  'MilesCranmer/SymbolicRegression.jl',
#  'vvvvalvalval/scope-capture',
#  'jonkrohn/DLTFpT',
#  'rfc2822/GfxTablet',
#  'sho5nn/ZDepthShadow',
#  'IndustryEssentials/ymir',
#  'ducafecat/flutter_ducafecat_news_getx',
#  'gottcode/focuswriter',
#  'jjcheer/ocrcn_tf2',
#  'nvim-neorocks/rocks.nvim',
#  'react-guide/react-router-cn',
#  'hjmshi/PyTorch-LBFGS',
#  'multi-os-engine/multi-os-engine',
#  'sebarmeli/JAIL',
#  'dyc87112/SpringCloudBook',
#  'waylife/RedEnvelopeAssistant',
#  'jpadilla/django-dotenv',
#  'john-doherty/swiped-events',
#  'apollographql/apollo-fetch',
#  'wanguano/Music163-React',
#  'pqrs-org/Seil',
#  'WisdomShell/codeshell-vscode',
#  'presscustomizr/hueman',
#  'VivienCormier/UIImageViewModeScaleAspect',
#  'liuguangqiang/Idaily',
#  'lawloretienne/Trestle',
#  'CodingTrain/Suggestion-Box',
#  'lapo-luchini/asn1js',
#  'kongnanlive/android-combination-avatar',
#  'jbrewer/Responsive-Measure',
#  'irfaan008/OnePageSigninSignup',
#  'guo-yu/candy',
#  'aderyabin/sniffer',
#  'perfectline/validates_url',
#  'imvast/Discord-Account-Creator',
#  'HimitZH/HOJ',
#  'antvis/XFlow',
#  'hexojs/hexo-deployer-git',
#  'slackapi/java-slack-sdk',
#  'MCRcortex/nekodetector',
#  'craigkerstiens/postgresguide.com',
#  'emilbayes/secure-password',
#  'speric/kindle-highlights',
#  'postcss/postcss-bem-linter',
#  'thewei/react-native-store',
#  'lvming6816077/LMVideoTest',
#  'mdubourg001/glci',
#  'lionsharecapital/lionshare-desktop',
#  'JasonHHouse/gaps',
#  'phpclassic/php-shopify',
#  'AlexAltea/unicorn.js',
#  'pimoroni/inky',
#  '0xairdropfarmer/medium-clone-on-node',
#  'qtile/qtile-examples',
#  'riscv-software-src/riscv-pk',
#  'tidymodels/parsnip',
#  'andreafioraldi/frida-fuzzer',
#  'laCour/slack-night-mode',
#  'implus/GFocal',
#  'nathco/Generate-GIF',
#  'binarylogic/authlogic_example',
#  'vuetwo/vuetron',
#  'googlecreativelab/Sprayscape',
#  'poteto/elixirconf-2016',
#  'briancollins/BCTabBarController',
#  'FaridSafi/react-native-basketball',
#  'zhaomenghuan/mui-demo',
#  'kreeben/resin',
#  'ldarren/QuickJS',
#  'takeoutweight/clojure-scheme',
#  'aker-gateway/Aker',
#  'thblt/write-yourself-a-git',
#  'iNavFlight/inav-configurator',
#  'sapegin/shipit',
#  'interactive-matter/aJson',
#  'grafijs/grafi',
#  'kentcdodds/genie',
#  'Robinlovelace/Creating-maps-in-R',
#  'openboleto/openboleto',
#  'adafruit/Adafruit_MQTT_Library',
#  'faob-dev/folding_cell',
#  'kingyoPiyo/Pico-10BASE-T',
#  'JokerJohn/LIO_SAM_6AXIS',
#  'alexmingoia/purescript-pux',
#  'zaneCC/AndroidUPnPDemo',
#  'android-notes/auto-scroll-capture',
#  'mortberg/cubicaltt',
#  'twilio/twilio-video.js',
#  'ryanflorence/async-props',
#  'ricobeck/KFEpubKit',
#  'mozilla/ichnaea',
#  'Trevelopment/MZD-AIO',
#  'saintplay/vue-swatches',
#  'iost-official/go-iost',
#  'intmain/HairPowder',
#  'Rocketseat/comunidade',
#  'comp500/quilt-serverside-mods',
#  'Alvin-Zeng/Awesome-Temporal-Action-Localization',
#  'podo/awesome-framer',
#  'aacotroneo/laravel-saml2',
#  'microsoft/vscode-textmate',
#  'rotators/Fo1in2',
#  'dwightjack/vue-types',
#  'nathom/filetype.nvim',
#  'Aruelius/cloud189',
#  'velopert/learning-react',
#  'greymass/anchor',
#  'martomo/SublimeTextXdebug',
#  'confuser/graphql-constraint-directive',
#  'dxa4481/WPA2-HalfHandshake-Crack',
#  'igorm84/spotify-astro-transitions',
#  'Netflix/edda',
#  'NodeArt/angular-commerce',
#  'naturalatlas/node-gdal',
#  'OedoSoldier/sd-webui-image-sequence-toolkit',
#  'stamen/modestmaps-js',
#  'dapphp/securimage',
#  'clowwindy/shadowsocks-libev',
#  'n0bel/PiClock',
#  'xamarin/docs-archive',
#  'vita-epfl/CrowdNav',
#  'thquinn/DraggableGridView',
#  'cnjackchen/my-chrome',
#  'JohnEarnest/Mako',
#  'MscrmTools/XrmToolBox',
#  'incu6us/goimports-reviser',
#  'IBM/spring-boot-microservices-on-kubernetes',
#  'PhantomInsights/baby-names-analysis',
#  'kmkz/Pentesting',
#  'stripe-archive/safesql',
#  'andreasbovens/understanding-viewport',
#  'linkedin/LayoutTest-iOS',
#  'xjdrew/gotunnel',
#  'Pizzabelly/EasyRP',
#  'BoyCook/TwitterJSClient',
#  'apertureless/vue-password-strength-meter',
#  'inkooboo/thread-pool-cpp',
#  'stefanprodan/k8s-prom-hpa',
#  'andremm/typedlua',
#  'WhiteHouse/fb_messenger_bot',
#  'Chrisvin/RubberPicker',
#  'fabiomsr/from-java-to-kotlin',
#  'akshay2211/MusicWave',
#  'bogerchan/Nier-Visualizer',
#  'kritzikratzi/Oscilloscope',
#  'Baidu-AIP/java-sdk',
#  'maciejhirsz/json-rust',
#  'josdirksen/learning-threejs-third',
#  'browserify/brfs',
#  'cfzd/Ultra-Fast-Lane-Detection-v2',
#  'lpty/nlp_base',
#  'tlswg/tls13-spec',
#  'nefelim4ag/Ananicy',
#  'envault/envault',
#  'openlookeng/hetu-core',
#  'FDA/openfda',
#  'danielwelch/hassio-zigbee2mqtt',
#  'linux-sunxi/sunxi-tools',
#  'avioli/uni_links',
#  'antoniogarrote/rdfstore-js',
#  'nusmodifications/nusmods',
#  'alfa-laboratory/arui-feather',
#  'hjwdzh/ManifoldPlus',
#  'pallets-eco/flask-jwt',
#  'kswedberg/jquery-tmbundle',
#  'lovezzzxxx/liverecord',
#  'Evernote/evernote-sdk-js',
#  'itsbonczek/kingpin',
#  'gjaldon/ecto_enum',
#  'kswedberg/jquery-tmbundle',
#  'lovezzzxxx/liverecord',
#  'Evernote/evernote-sdk-js',
#  'MishaLaskin/curl',
#  'ConsenSys-Academy/Blockchain-Developer-Bootcamp',
#  'MolecularAI/aizynthfinder',
#  'TaoRuijie/ECAPA-TDNN',
#  'LinkedInAttic/cleo',
#  'xoxco/breakpoints',
#  'chadaustin/sajson',
#  'IVMachiavelli/OSINT_Team_Links',
#  'marshall/logcat-color',
#  'FasterXML/jackson-dataformat-xml',
#  'featurist/coypu',
#  'VFansss/mgs2-v-s-fix',
#  'jazzband/django-admin-sortable',
#  'zhangshuiyong/nodequant',
#  'realm/SwiftCov',
#  'ksvc/KSYMediaPlayer_iOS',
#  'ramonhagenaars/nptyping',
#  'ymgd/codereader',
#  'onmyway133/EasyConfetti',
#  'crosbymichael/slex',
#  'metaskills/less-rails-bootstrap',
#  'xsc/lein-ancient',
#  'mcrovero/rubber',
#  'mozilla/positron',
#  'stepchowfun/typical',
#  'tc39/proposal-bigint',
#  'cherokee/webserver',
#  'DataXujing/YOLOv8',
#  'LendingHome/zero_downtime_migrations',
#  'RobbieHan/gistandard',
#  'thewhitetulip/Tasks',
#  'dobarkod/django-queryinspect',
#  'husky-dev/SAMultisectorControl',
#  'dodie/vim-disapprove-deep-indentation',
#  'facebookresearch/OctConv',
#  'apicollective/apibuilder',
#  'sastraxi/pgsh',
#  'MarvinTeichmann/ConvCRF',
#  'chrismiles/DynamicXray',
#  'tcort/markdown-link-check',
#  'dmroeder/pylogix',
#  'sebastiencs/company-box',
#  'ZupIT/ritchie-cli',
#  'diwu/DWURecyclingAlert',
#  'kadirahq/fast-render',
#  'MosheBerman/MBCalendarKit',
#  'alexcorvi/anchorme.js',
#  'WordPress/dashicons',
#  'spatie/string',
#  'Kink3d/kMirrors',
#  'sindresorhus/jshint-stylish',
#  'mrdulin/blog',
#  'Carbs0126/ExpandableTextView',
#  'SteffeyDev/react-native-popover-view',
#  'Colt/YelpCamp',
#  'AttackXiaoJinJin/reactExplain',
#  'confucianzuoyuan/bookstore',
#  'Xerios/ScreenManager',
#  'govizlora/optical-breacher',
#  'arturdm/jacoco-android-gradle-plugin',
#  'gamaral/rpi-buildroot',
#  'the-teacher/the_sortable_tree',
#  'percona/PerconaFT',
#  'atom/tree-view',
#  'theotherp/nzbhydra',
#  'pwnall/node-open',
#  'ember-cli-deploy/ember-cli-deploy',
#  'watson-developer-cloud/personality-insights-nodejs',
#  'ajoslin/angular-promise-tracker',
#  'ryanflorence/example-react-router-server-rendering-lazy-routes',
#  'relay-tools/react-router-relay',
#  'sunng87/node-geohash',
#  'ahmedfgad/NumPyCNN',
#  'ChristianUlbrich/awesome-microfrontends',
#  'Jaykul/PowerLine',
#  'turtle0x1/LxdMosaic',
#  'itsjavi/fontawesome-iconpicker',
#  'tpope/heroku-fucking-console',
#  'bahmutov/next-update',
#  'tunabrain/tantalum',
#  'kartik-v/yii2-widgets',
#  'lukeed/regexparam',
#  'barsoom/attr_extras',
#  'headllines/hackernews-daily',
#  'anasfik/flutter-spy',
#  'ceccopierangiolieugenio/pyTermTk',
#  'maxdev1/ghost',
#  'kaixueio/kaixue-docs',
#  'alskipp/ASScreenRecorder',
#  'ignacio-rocco/detectorch',
#  'flipace/lovli.js',
#  'cloudkj/layer',
#  'Eilonh/s3crets_scanner',
#  'bluebird75/luaunit',
#  'closeio/ciso8601',
#  'VcDevel/std-simd',
#  'G4lile0/Heimdall-WiFi-Radar',
#  'concretecms/concrete5-legacy',
#  'calderajs/caldera-react',
#  'itsbonczek/kingpin',
#  'gjaldon/ecto_enum',
#  'vgsatorras/few-shot-gnn',
#  'cenkai88/vue-svg-icon',
#  'nylas/nylas-perftools',
#  'pallets-eco/flask-jwt',
#  'mdipierro/workflow',
#  'lookingstars/nuomi',
#  'aws-samples/amazon-personalize-samples',
#  'tj/serve',
#  'taivop/awesome-data-annotation',
#  'MobSF/mobsfscan',
#  'LetsDefend/awesome-soc-analyst',
#  'eslint/config-inspector',
#  'lorenzofiamingo/swiftui-cached-async-image',
#  'tal-tech/fend',
#  'GoVanguard/list-infosec-encyclopedia',
#  '19wu/19wu',
#  'rplevy/swiss-arrows',
#  'martinruenz/maskfusion',
#  'kswedberg/jquery-tmbundle',
#  'LinkedInAttic/cleo',
#  'xoxco/breakpoints',
#  'chadaustin/sajson',
#  'IVMachiavelli/OSINT_Team_Links',
#  'marshall/logcat-color',
#  'lixi5338619/lxBook',
#  'shree1999/Data-Structures-and-Algorithms',
#  'TooTallNate/plist.js',
#  'victoryhb/streamlit-option-menu',
#  'scrollback/scrollback',
#  'FasterXML/jackson-dataformat-xml',
#  'featurist/coypu',
#  'pmiaowu/HostCollision',
#  'btcpayserver/btcpayserver-docker',
#  'Rufus31415/Simple-WebXR-Unity',
#  'ccsb-scripps/AutoDock-Vina',
#  'digitalinnovationone/js-developer-pokedex',
#  'realm/SwiftCov',
#  'rustwasm/rust-webpack-template',
#  'ymgd/codereader',
#  'smartcontracts/ethereum-book',
#  'sjr7/seckill',
#  'lwjglgamedev/lwjglbook-leg',
#  'bhamrick/multitwitch',
#  's0md3v/goop',
#  'remix-pwa/remix-pwa',
#  'N0rz3/Zehef',
#  'ncase/joy',
#  'open-nomie/nomie5',
#  'dirkvranckaert/AndroidDecompiler',
#  'getsentry/raven-go',
#  'lookfirst/sardine',
#  'AugustRush/ARAnimation',
#  'onmyway133/EasyConfetti',
#  'crosbymichael/slex',
#  'akd-io/create-next-stack',
#  'gilmarsquinelato/i18n-manager',
#  'wh200720041/iscloam',
#  'GantMan/jail-monkey',
#  'metaskills/less-rails-bootstrap',
#  'LendingHome/zero_downtime_migrations',
#  'RobbieHan/gistandard',
#  'thewhitetulip/Tasks',
#  'dobarkod/django-queryinspect',
#  'PacktPublishing/TensorFlow-Machine-Learning-Cookbook',
#  'eleurent/rl-agents',
#  'ihaolin/antares',
#  'graalvm/graalvm-demos',
#  'GSA/data.gov',
#  'bignerdranch/CoreDataStack',
#  'laurihy/angular-payments',
#  'dodie/vim-disapprove-deep-indentation',
#  'facebookresearch/OctConv',
#  'apicollective/apibuilder',
#  'sastraxi/pgsh',
#  'MarvinTeichmann/ConvCRF',
#  'Netflix/blitz4j',
#  'stuhli/awesome-event-ids',
#  'status-im/nimbus-eth1',
#  'flschweiger/reply',
#  'ccwav/QLScript2',
#  'ZupIT/ritchie-cli',
#  'duolatech/xapimanager',
#  'lammertb/libcrc',
#  'n0shake/clocker',
#  'jenkinsci/pipeline-model-definition-plugin',
#  'Polish-Miko/GravityEngine',
#  'patricktalmadge/bootstrapper',
#  'session-replay-tools/tcpburn',
#  'kadirahq/fast-render',
#  'MosheBerman/MBCalendarKit',
#  'alexcorvi/anchorme.js',
#  'WordPress/dashicons',
#  'chenxin-dlut/TransT',
#  'susam/muboard',
#  'TheLarkInn/webpack-workshop-2018',
#  'tsl0922/ImPlay',
#  'BartoszMilewski/Okasaki',
#  'jdantonio/functional-ruby',
#  'calebhearth/formulaic',
#  'get-eventually/eventually-rs',
#  '13812851221/-rxrw-daily_morning',
#  'myndzi/wtfnode',
#  'dhruvasagar/vim-dotoo',
#  'longcw/RoIAlign.pytorch',
#  'preshing/turf',
#  'jonathanslenders/asyncio-redis',
#  'jupiterjs/jquerymx',
#  'rmm5t/strip_attributes',
#  'pandolia/easy-service',
#  'JDAI-CV/centerX',
#  'anthonya1999/GoodNight',
#  'mapbox/mapnik-vector-tile',
#  'martinwells/objects.js',
#  'hortonworks-spark/shc',
#  'kharvd/gpt-cli',
#  'bab2min/tomotopy',
#  'stakewithus/defi-by-example',
#  'leemeichin/say-cheese',
#  'SINTEF-9012/PruneCluster',
#  'justjavac/1s',
#  'googlearchive/android-viewpager2',
#  'mamaral/MAThemeKit',
#  'movehand/raisr',
#  'ja9er/Gofreeproxy',
#  'rspivak/slimit',
#  'yatish27/linkedin-scraper',
#  'chibicode/TypeScript-for-Beginner-Programmers',
#  'fengzhizi715/ProxyPool',
#  'chernivtsijs/made-in-ukraine',
#  'auth0/SimpleKeychain',
#  'Accenture/jenkins-attack-framework',
#  'coredns/deployment',
#  'minooo/React-Study',
#  'mbrochh/vim-as-a-python-ide',
#  'drakeet/Floo',
#  'laravel/nova-issues',
#  'thulab/DeepHash',
#  'uber-research/go-explore',
#  'chef-boneyard/vagrant-omnibus',
#  'Mochengvia/PanuonUI',
#  'peterkeen/dokuen',
#  'boycechang/BCMagicTransition',
#  'maxwells/bootstrap-tags',
#  'Paper99/SRFBN_CVPR19',
#  'yipengmu/react-native-android-lession',
#  'TakeScoop/SwiftyButton',
#  'MCGallaspy/dr_strangetemplate',
#  'tomsoft1/StackBluriOS',
#  'mthbernardes/rsg',
#  'starburst1977/readium',
#  'g0tmi1k/os-scripts',
#  'liuhuanyong/ChainKnowledgeGraph',
#  'RelevanceAI/vectorhub',
#  'automateyournetwork/automate_your_network',
#  'wpengine/frost',
#  'rnevius/minimal-django',
#  'heroku/heroku-accounts',
#  'ENFOS/FlowupLabels.js',
#  'onedayitwillmake/RealtimeMultiplayerNodeJs',
#  'astrails/dotvim',
#  'emailjs/emailjs-imap-client',
#  'rbignon/doctoshotgun',
#  'okdalto/VisualizeMNIST',
#  'mariusae/trickle',
#  'it-rico/ZrcListView',
#  'drewblas/aws-ses',
#  'sstephenson/global_phone',
#  'briis/unifiprotect',
#  'blockchain-jd-com/jdchain',
#  'lucasr/probe',
#  'dixonzhao/Basic_Study',
#  'brentvatne/react-native-animated-demo-tinder',
#  'Spikef/react-native-gesture-password',
#  'glenyi/FloatRatingView',
#  'kogakure/gitweb-theme',
#  'langhsu/mblog',
#  '373675032/moti-cloud',
#  'google/webauthndemo',
#  'Kilian/f.lux-indicator-applet',
#  'airlift/aircompressor',
#  'makeomatic/redux-connect',
#  'hecomi/uREPL',
#  'jlondiche/job-board-php',
#  'r-spatial/stars',
#  'hprose/hprose-java',
#  'slashdotdash/jekyll-lunr-js-search',
#  'DONGChuan/Yummy-Jekyll',
#  'bportaluri/WiFiEsp',
#  'jessfraz/gmailfilters',
#  'aceisScope/WaterflowView',
#  'iitzco/faced',
#  'santinic/pampy.js',
#  'tkf/emacs-ipython-notebook',
#  'marcj/jquery-selectBox',
#  'Tencent/Fanvas',
#  'prooph/event-store',
#  'ilovepose/DarkPose',
#  'aozora/bootplus',
#  'krzysztofzablocki/crafter',
#  'lukeed/dimport',
#  'yyx990803/launch-editor',
#  'ecomfe/edp',
#  '1buran/rHttp',
#  'reactiveui/Camelotia',
#  '252860883/ArtQRCode',
#  'leverdeterre/JMHoledView',
#  'petehunt/react-boilerplate',
#  'alexkuz/react-dock',
#  'Tatamo/atcoder-cli',
#  'padolsey-archive/jquery.lint--old',
#  'underdash/underdash',
#  'RamWire/NinaPagerView',
#  'blockloop/scan',
#  'flutter/games',
#  'john30/ebusd',
#  'jDataView/jDataView',
#  'malsup/corner',
#  'larsonjj/generator-yeogurt',
#  'colinmorris/SongSim',
#  'webark/ember-component-css',
#  'dg/twitter-php',
#  'SmartDengg/RxBlur',
#  'LinkedDestiny/swoole-src-analysis',
#  'zedshaw/python-lust',
#  'sgolivernet/curso-android-src',
#  'dvdzkwsk/react-reformed',
#  'karma-runner/karma-jasmine',
#  'thubbo/awesome-dubbo',
#  'orta/pragmatic-testing',
#  'cseagle/sk3wldbg',
#  'jremmen/vim-ripgrep',
#  'UPC/ravada',
#  'n8/multi_fetch_fragments',
#  'kaievns/ruby-fighter',
#  'microsoft/thrifty',
#  ...]

# %%
from github import Github
def get_topics(repo):
    if repo.get_topics():
        return repo.get_topics()[0:10]
    else :
        return 'No topics'
    
# 用你的 GitHub 访问令牌替换
ACCESS_TOKEN = ''

# 初始化 Github 客户端
g = Github(ACCESS_TOKEN)

for repo_name in REPO_LIST:
    print(f"begin getting {repo_name}")
    repo = g.get_repo(repo_name)
    repo_info = {
        "Repository Name": repo_name,
        "Topics": get_topics(repo)
    }
    new_data_list = {key: [value] for key, value in repo_info.items()}
    df = pd.DataFrame(new_data_list)
    df.to_csv('repos_info_new_topic.csv', mode='a', header=False, index=False)
# Out:
# begin getting hiroi-sora/Umi-OCR
# begin getting MostlyAdequate/mostly-adequate-guide
# begin getting StreisandEffect/streisand
# begin getting youzan/vant
# begin getting gfwlist/gfwlist
# begin getting electron-react-boilerplate/electron-react-boilerplate
# begin getting kovidgoyal/kitty
# begin getting gocolly/colly
# begin getting responsively-org/responsively-app
# begin getting HeroTransitions/Hero
# begin getting Swordfish90/cool-retro-term
# begin getting opentofu/opentofu
# begin getting dylanaraps/neofetch
# begin getting pugjs/pug
# begin getting dandavison/delta
# begin getting julycoding/The-Art-Of-Programming-By-July-2nd
# begin getting typicode/lowdb
# begin getting ColorlibHQ/gentelella
# begin getting duckdb/duckdb
# begin getting pubkey/rxdb
# begin getting FelisCatus/SwitchyOmega
# begin getting emilk/egui
# begin getting JohnCoates/Aerial
# begin getting ajeetdsouza/zoxide
# begin getting petkaantonov/bluebird
# begin getting keepassxreboot/keepassxc
# begin getting graphql/graphql-js
# begin getting Bin-Huang/chatbox
# begin getting ungoogled-software/ungoogled-chromium
# begin getting SBoudrias/Inquirer.js
# begin getting zellij-org/zellij
# begin getting facebookarchive/pop
# begin getting thangchung/awesome-dotnet-core
# begin getting karpathy/minGPT
# begin getting timqian/chinese-independent-blogs
# begin getting vueuse/vueuse
# begin getting tobiasahlin/SpinKit
# begin getting wekan/wekan
# begin getting airbnb/visx
# begin getting knex/knex
# begin getting slimtoolkit/slim
# begin getting simdjson/simdjson
# begin getting scottbez1/smartknob
# begin getting jcjohnson/neural-style
# begin getting wasmerio/wasmer
# begin getting mysqljs/mysql
# begin getting RustPython/RustPython
# begin getting SnapKit/Masonry
# begin getting SigNoz/signoz
# begin getting vim-airline/vim-airline
# begin getting crewAIInc/crewAI
# begin getting wangeditor-team/wangEditor
# begin getting LMAX-Exchange/disruptor
# begin getting nvim-lua/kickstart.nvim
# begin getting vectordotdev/vector
# begin getting lxgw/LxgwWenKai
# begin getting wilsonfreitas/awesome-quant
# begin getting reddit-archive/reddit
# begin getting browsh-org/browsh
# begin getting plotly/plotly.js
# begin getting gleam-lang/gleam
# begin getting lottie-react-native/lottie-react-native
# begin getting air-verse/air
# begin getting alsotang/node-lessons
# begin getting Mikubill/sd-webui-controlnet
# begin getting briannesbitt/Carbon
# begin getting ether/etherpad-lite
# begin getting terrastruct/d2
# begin getting go-playground/validator
# begin getting MarlinFirmware/Marlin
# begin getting android/nowinandroid
# begin getting jmoiron/sqlx
# begin getting thunlp/GNNPapers
# begin getting altercation/solarized
# begin getting umijs/qiankun
# begin getting spf13/spf13-vim
# begin getting uber-go/guide
# begin getting bvaughn/react-window
# begin getting meta-llama/codellama
# begin getting OptimalBits/bull
# begin getting InterviewReady/system-design-resources
# begin getting whyour/qinglong
# begin getting greyireland/algorithm-pattern
# begin getting RealKai42/qwerty-learner
# begin getting kailashahirwar/cheatsheets-ai
# begin getting cmusatyalab/openface
# begin getting microsoft/IoT-For-Beginners
# begin getting sass/sass
# begin getting airbnb/react-sketchapp
# begin getting automerge/automerge-classic
# begin getting microsoft/Bringing-Old-Photos-Back-to-Life
# begin getting deepset-ai/haystack
# begin getting rust-lang/book
# begin getting TGSAN/CMWTAT_Digital_Edition
# begin getting hapijs/hapi
# begin getting Konloch/bytecode-viewer
# begin getting PavelDoGreat/WebGL-Fluid-Simulation
# begin getting rocksdanister/lively
# begin getting apple/foundationdb
# begin getting Infisical/infisical
# begin getting acidanthera/OpenCorePkg
# begin getting philipwalton/solved-by-flexbox
# begin getting LemmyNet/lemmy
# begin getting google-deepmind/deepmind-research
# begin getting edgedb/edgedb
# begin getting scipy/scipy
# begin getting AI4Finance-Foundation/FinGPT
# begin getting greenrobot/greenDAO
# begin getting postmanlabs/httpbin
# begin getting tmuxinator/tmuxinator
# begin getting SFTtech/openage
# begin getting google/guice
# begin getting Automattic/wp-calypso
# begin getting twpayne/chezmoi
# begin getting mwaskom/seaborn
# begin getting ttroy50/cmake-examples
# begin getting PrismJS/prism
# begin getting jedisct1/libsodium
# begin getting humiaozuzu/awesome-flask
# begin getting Chalarangelo/30-seconds-of-interviews
# begin getting haiwen/seafile
# begin getting langchain-ai/langchainjs
# begin getting slimphp/Slim
# begin getting rougier/numpy-100
# begin getting matrix-org/synapse
# begin getting Embedding/Chinese-Word-Vectors
# begin getting peng-zhihui/Dummy-Robot
# begin getting Matt-Esch/virtual-dom
# begin getting Unity-Technologies/UnityCsReference
# begin getting ansible/ansible-examples
# begin getting barbajs/barba
# begin getting ionic-team/capacitor
# begin getting frank-lam/fullstack-tutorial
# begin getting summernote/summernote
# begin getting Nuitka/Nuitka
# begin getting MatsuriDayo/nekoray
# begin getting careercup/CtCI-6th-Edition
# begin getting p8952/bocker
# begin getting mzlogin/awesome-adb
# begin getting girliemac/a-picture-is-worth-a-1000-words
# begin getting cjwirth/awesome-ios-ui
# begin getting jordansissel/fpm
# begin getting rust-lang/rust-clippy
# begin getting doctrine/lexer
# begin getting ludwig-ai/ludwig
# begin getting Pawdroid/Free-servers
# begin getting TodePond/DreamBerd
# begin getting shuding/nextra
# begin getting lengstrom/fast-style-transfer
# begin getting hackstoic/golang-open-source-projects
# begin getting future-architect/vuls
# begin getting magicalpanda/MagicalRecord
# begin getting liu673cn/bug
# begin getting mas-cli/mas
# begin getting aristocratos/bashtop
# begin getting rushter/MLAlgorithms
# begin getting systemdesign42/system-design
# begin getting infracost/infracost
# begin getting JamesNK/Newtonsoft.Json
# begin getting shiburagi/Drawer-Behavior
# begin getting tastejs/PropertyCross
# begin getting laihuamin/JS-total
# begin getting little2s/NoChat
# begin getting jeasonlzy/PullZoomView
# begin getting steveruizok/perfect-cursors
# begin getting hseeberger/akka-http-json
# begin getting reinder42/SwiftCheatsheet
# begin getting mcedit/mcedit
# begin getting python-needle/needle
# begin getting chrislloyd/gravtastic
# begin getting castorini/hedwig
# begin getting commonsguy/cwac-merge
# begin getting kaleai/ActivityOptionsICS
# begin getting FrontEndRoad/HTML5-FAQ
# begin getting JadenZhong/wechat-flutter
# begin getting JacksonWuxs/DaPy
# begin getting shaojiankui/ProfilesManager
# begin getting hx173149/C3D-tensorflow
# begin getting twitter-archive/twitter-text-objc
# begin getting threedaymonk/text
# begin getting kangshaojun/flutter-book
# begin getting ole/OLEContainerScrollView
# begin getting TMRh20/TMRpcm
# begin getting crysislinux/chrome-react-perf
# begin getting kriswallsmith/spork
# begin getting Jpadilla1/react-native-ios-charts
# begin getting ssola/python-flask-microservice
# begin getting saabi/vminpoly
# begin getting geowarin/boot-react
# begin getting Lattyware/unrpa
# begin getting ekmartin/slack-irc
# begin getting senny/emacs-eclim
# begin getting abarisain/dmix
# begin getting chrisvfritz/7-secret-patterns
# begin getting genemu/GenemuFormBundle
# begin getting yangxu4536/MeiTuanLocateCity
# begin getting zorkian/nagios-api
# begin getting tjfontaine/node-dns
# begin getting tomkrcha/drawscript
# begin getting infinitest/infinitest
# begin getting cthorey/CS231
# begin getting sromku/memory-game
# begin getting ryanmaxwell/UncrustifyX
# begin getting donobono/DoImagePickerController
# begin getting marload/DeepRL-TensorFlow2
# begin getting deckarep/gosx-notifier
# begin getting rodionovd/SWRoute
# begin getting FahimF/SQLiteDB
# begin getting szagoruyko/diracnets
# begin getting Almighty-Alpaca/JetBrains-Discord-Integration
# begin getting tenntenn/gopher-stickers
# begin getting vestrel00/contacts-android
# begin getting docker/libcompose
# begin getting joshwcomeau/redux-vcr
# begin getting nullobject/fkit
# begin getting philipwalton/responsive-components
# begin getting maxmx/bootstrap-stylus
# begin getting pragmaticly/smart-time-ago
# begin getting LinkedInAttic/datafu
# begin getting stomita/ios-imagefile-megapixel
# begin getting moonshawdo/checkgoogleip
# begin getting yannickl/Reactions
# begin getting daemon3000/InputManager
# begin getting jojozhai/security
# begin getting neolee/pilot
# begin getting OiPunk/OnlineTaxi
# begin getting beyondcode/laravel-credentials
# begin getting graphql-compose/graphql-compose-elasticsearch
# begin getting davidgohel/officer
# begin getting remirobert/CameraEngine
# begin getting arthur-e/Wicket
# begin getting Xilinx/u-boot-xlnx
# begin getting astro/gitpop
# begin getting ck86/main-bower-files
# begin getting CoderJackyHuang/HYBNetworking
# begin getting calvinmetcalf/catiline
# begin getting noveogroup/backbone.iobind
# begin getting firebreath/FireBreath
# begin getting TooTallNate/ansi-canvas
# begin getting alejandro-ao/langchain-ask-pdf
# begin getting utsuboco/r3f-perf
# begin getting jenzz/Android-UndoBar
# begin getting notofonts/noto-source
# begin getting hornhuang/android_interviews
# begin getting bguerout/jongo
# begin getting joelmoss/strano
# begin getting daniellmb/JavaScript-Scope-Context-Coloring
# begin getting alibaba/esim-response-selection
# begin getting manjula-dube/react-advanced-patterns
# begin getting JasonBai007/vue-seed
# begin getting vigetlabs/Twitter-Bootstrap-for-Omnigraffle
# begin getting ldiqual/tesseract-ios
# begin getting kristopolous/TickTick
# begin getting lasso-js/lasso
# begin getting Yelp/yelp-api
# begin getting keen/keen-js
# begin getting noelportugal/google-home-notifier
# begin getting cocagne/paxos
# begin getting chris104957/maildown
# begin getting dkwingsmt/haha
# begin getting AtomLinter/linter-eslint
# begin getting szagoruyko/functional-zoo
# begin getting docker/libcompose
# begin getting joshwcomeau/redux-vcr
# begin getting linkedin/pygradle
# begin getting drewr/postal
# begin getting nullobject/fkit
# begin getting ledokku/ledokku
# begin getting rubyjs/mini_racer
# begin getting tenderlove/rails_autolink
# begin getting maxmx/bootstrap-stylus
# begin getting pragmaticly/smart-time-ago
# begin getting LinkedInAttic/datafu
# begin getting stomita/ios-imagefile-megapixel
# begin getting udacity/ud862-samples
# begin getting speed/newcrawler
# begin getting soyking/e3w
# begin getting openenergymonitor/EmonLib
# begin getting squeryl/squeryl
# begin getting nstrayer/datadrivencv
# begin getting github/maven-plugins
# begin getting ming1016/STMURLCache
# begin getting lorensiuswlt/NewQuickAction
# begin getting paddybyers/anode
# begin getting neolee/pilot
# begin getting OiPunk/OnlineTaxi
# begin getting beyondcode/laravel-credentials
# begin getting nwojke/cosine_metric_learning
# begin getting yoyofx/yoyogo
# begin getting BetterJS/doc
# begin getting devopsbookmarks/devopsbookmarks.com
# begin getting graphql-compose/graphql-compose-elasticsearch
# begin getting davidgohel/officer
# begin getting flouthoc/calc.asm
# begin getting gradiuscypher/infosec_getting_started
# begin getting Kofktu/KUIPopOver
# begin getting remirobert/CameraEngine
# begin getting ant-design/create-react-app-antd
# begin getting mrdoob/htmleditor
# begin getting EasyTuan/mui-kidApp
# begin getting signalapp/libsignal-service-java
# begin getting timeglass/glass
# begin getting bradfitz/exp-httpclient
# begin getting jtriley/StarCluster
# begin getting PKRoma/ProcessHacker
# begin getting nforest/awesome-decompilation
# begin getting jankais3r/LLaMA_MPS
# begin getting huacnlee/social-share-button
# begin getting fxia22/stn.pytorch
# begin getting noveogroup/backbone.iobind
# begin getting firebreath/FireBreath
# begin getting codebrainz/geany-themes
# begin getting alstr/todo-to-issue-action
# begin getting cacheflowe/creative-coding-notes
# begin getting motion-planning/rrt-algorithms
# begin getting utsuboco/r3f-perf
# begin getting ucbdrive/bdd100k
# begin getting jenzz/Android-UndoBar
# begin getting notofonts/noto-source
# begin getting GFNOrg/gflownet
# begin getting hornhuang/android_interviews
# begin getting bguerout/jongo
# begin getting joelmoss/strano
# begin getting avinassh/grpc-errors
# begin getting alphaSeclab/sec-tool-list
# begin getting sxyazi/free-hls
# begin getting daniellmb/JavaScript-Scope-Context-Coloring
# begin getting timothycrosley/jiphy
# begin getting JasonBai007/vue-seed
# begin getting vigetlabs/Twitter-Bootstrap-for-Omnigraffle
# begin getting kristopolous/TickTick
# begin getting ifitdoesntwork/DAExpandAnimation
# begin getting lasso-js/lasso
# begin getting cbschuld/Browser.php
# begin getting emersion/xdg-desktop-portal-wlr
# begin getting LuciferHuang/heimdallr-sdk
# begin getting Yelp/yelp-api
# begin getting keen/keen-js
# begin getting noelportugal/google-home-notifier
# begin getting ampproject/amp.dev
# begin getting dappuniversity/nft
# begin getting togayther/react-native-cnblogs
# begin getting emacs-php/php-mode
# begin getting adidas/adidas-devops-maturity-framework
# begin getting staticallyio/statically
# begin getting xsank/webssh
# begin getting google/palette.js
# begin getting matthewmueller/socrates
# begin getting comex/substitute
# begin getting chiemy/CardView
# begin getting ethereum-optimism/cannon
# begin getting darsain/fpsmeter
# begin getting angular-ui/ui-ace
# begin getting josephmisiti/generic-django-project
# begin getting ai/audio-recorder-polyfill
# begin getting OpnTec/thai.opentech.asia
# begin getting bfirsh/jsnes-web
# begin getting javaee/javamail
# begin getting aave/flashloan-box
# begin getting weishen250/npscrack
# begin getting bobbyiliev/introduction-to-git-and-github-ebook
# begin getting inverse-scaling/prize
# begin getting in28minutes/java-cheat-sheet
# begin getting gavin66/proxy_list
# begin getting resir014/react-redux-typescript-example
# begin getting hkociemba/RubiksCube-TwophaseSolver
# begin getting google/cctz
# begin getting yuhua-chen/MCLog
# begin getting tenntenn/gopher-stickers
# begin getting vestrel00/contacts-android
# begin getting jariz/MaterialUp
# begin getting ericsomdahl/python-bittrex
# begin getting kimmelsg/cj-upload
# begin getting PaNaVTEC/DrawableView
# begin getting javasmall/bigsai-algorithm
# begin getting BrianSidebotham/arm-tutorial-rpi
# begin getting aashrafh/Mozart
# begin getting tailwindcomponents/dashboard
# begin getting opencomputeproject/onie
# begin getting davidpdrsn/todo-or-die
# begin getting iMoonLab/DeepHypergraph
# begin getting docker/libcompose
# begin getting tenderlove/rails_autolink
# begin getting twisted/treq
# begin getting WICG/scroll-to-text-fragment
# begin getting vinipsmaker/tufao
# begin getting samarth-p/College-ERP
# begin getting dropbox/dropbox-sdk-java
# begin getting vermont42/Podcasts
# begin getting orhanobut/wasp
# begin getting Dewera/Lunar
# begin getting cwilso/midi-synth
# begin getting smsohan/MvcMailer
# begin getting jxnblk/ram
# begin getting Spreadsheets/WickedGrid
# begin getting ryan-roemer/sphinx-bootstrap-theme
# begin getting madongqiang2201/views
# begin getting picoruby/picoruby
# begin getting zju3dv/EasyVolcap
# begin getting orwagodfather/WordList
# begin getting PKM-er/media-extended
# begin getting EalenXie/spring-microservice-ddd
# begin getting RoboStack/jupyter-ros
# begin getting go-share-team/go_interview
# begin getting FluxML/FastAI.jl
# begin getting nstevens/androidguide
# begin getting dpnishant/jsprime
# begin getting AlexChesser/recruiter-autoresponse
# begin getting aws-samples/lambda-refarch-mobilebackend
# begin getting maxmx/bootstrap-stylus
# begin getting stomita/ios-imagefile-megapixel
# begin getting alekseyn/EasyTableView
# begin getting cvkki/src
# begin getting melisgl/mgl
# begin getting hjkl01/pornhub
# begin getting swyxio/devtools-angels
# begin getting google-developer-training/pwa-training-labs
# begin getting 6eer/uniswap-sushiswap-arbitrage-bot
# begin getting aws/aws-sdk-rails
# begin getting github/maven-plugins
# begin getting ming1016/STMURLCache
# begin getting lorensiuswlt/NewQuickAction
# begin getting paddybyers/anode
# begin getting challenger-deep-theme/vim
# begin getting ANSSI-FR/rust-guide
# begin getting google/u2f-ref-code
# begin getting LoupVaillant/Monocypher
# begin getting mdozmorov/scRNA-seq_notes
# begin getting Boddlnagg/midir
# begin getting JuliaRegistries/General
# begin getting moonshawdo/checkgoogleip
# begin getting yannickl/Reactions
# begin getting daemon3000/InputManager
# begin getting rollin0-0/DiffHelper
# begin getting MahdiMashrur/Awesome-Application-Security-Checklist
# begin getting PreOS-Security/awesome-firmware-security
# begin getting TTimo/GtkRadiant
# begin getting ThePrimeagen/htmx-lsp
# begin getting yangshun/top-javascript-interview-questions
# begin getting xmuSistone/android-snake-menu
# begin getting katef/kgt
# begin getting google/easypki
# begin getting jqr/heroku_san
# begin getting neolee/pilot
# begin getting OiPunk/OnlineTaxi
# begin getting beyondcode/laravel-credentials
# begin getting supersheep/wechat-pay
# begin getting StreetVoice/HysteriaPlayer
# begin getting HenrikJoreteg/redux-bundler
# begin getting bdarnell/torndb
# begin getting domenic/svg2png
# begin getting tumobi/nideshop-admin
# begin getting Sjj1024/douyin-live
# begin getting chubin/cheat.sheets
# begin getting abhishekkrthakur/diffuzers
# begin getting EasyTuan/mui-kidApp
# begin getting signalapp/libsignal-service-java
# begin getting timeglass/glass
# begin getting bradfitz/exp-httpclient
# begin getting TheNewNormal/kube-solo-osx
# begin getting mozilla/moz-sql-parser
# begin getting teambition/then.js
# begin getting iatek/bootstrap-zero
# begin getting iamshaunjp/typescript-tutorial
# begin getting songdejia/EAST
# begin getting glomadrian/dashed-circular-progress
# begin getting ffffffff0x/Pentest101
# begin getting asafdav/ng-csv
# begin getting htmlx-org/HTMLx
# begin getting l3uddz/traktarr
# begin getting dotnetcore/SmartCode
# begin getting threedr3am/ZhouYu
# begin getting APIDevTools/swagger-express-middleware
# begin getting twitter/ios-twitter-network-layer
# begin getting soarcn/UndoBar
# begin getting vaneenige/unswitch
# begin getting sciyoshi/pyfacebook
# begin getting jaubourg/jquery-jsonp
# begin getting TryGOTry/DogCs4.4
# begin getting Mamboleoo/DecorativeBackgrounds
# begin getting luozhaohui/books
# begin getting alibaba/Pai-Megatron-Patch
# begin getting jerry1993-tech/Cornucopia-LLaMA-Fin-Chinese
# begin getting dazinovic/neural-rgbd-surface-reconstruction
# begin getting shprink/ionic-native-transitions
# begin getting MattSurabian/DuckHunt-JS
# begin getting libsm64/libsm64-blender
# begin getting Kevin-De-Koninck/Get-It
# begin getting phenomnomnominal/betterer
# begin getting cloudflare/react-gateway
# begin getting komljen/dockerfile-examples
# begin getting Bitwise-01/Loki
# begin getting MilesCranmer/SymbolicRegression.jl
# begin getting vvvvalvalval/scope-capture
# begin getting jonkrohn/DLTFpT
# begin getting rfc2822/GfxTablet
# begin getting sho5nn/ZDepthShadow
# begin getting IndustryEssentials/ymir
# begin getting ducafecat/flutter_ducafecat_news_getx
# begin getting gottcode/focuswriter
# begin getting jjcheer/ocrcn_tf2
# begin getting nvim-neorocks/rocks.nvim
# begin getting react-guide/react-router-cn
# begin getting hjmshi/PyTorch-LBFGS
# begin getting multi-os-engine/multi-os-engine
# begin getting sebarmeli/JAIL
# begin getting dyc87112/SpringCloudBook
# begin getting waylife/RedEnvelopeAssistant
# begin getting jpadilla/django-dotenv
# begin getting john-doherty/swiped-events
# begin getting apollographql/apollo-fetch
# begin getting wanguano/Music163-React
# begin getting pqrs-org/Seil
# begin getting WisdomShell/codeshell-vscode
# begin getting presscustomizr/hueman
# begin getting VivienCormier/UIImageViewModeScaleAspect
# begin getting liuguangqiang/Idaily
# begin getting lawloretienne/Trestle
# begin getting CodingTrain/Suggestion-Box
# begin getting lapo-luchini/asn1js
# begin getting kongnanlive/android-combination-avatar
# begin getting jbrewer/Responsive-Measure
# begin getting irfaan008/OnePageSigninSignup
# begin getting guo-yu/candy
# begin getting aderyabin/sniffer
# begin getting perfectline/validates_url
# begin getting imvast/Discord-Account-Creator
# begin getting HimitZH/HOJ
# begin getting antvis/XFlow
# begin getting hexojs/hexo-deployer-git
# begin getting slackapi/java-slack-sdk
# begin getting MCRcortex/nekodetector
# begin getting craigkerstiens/postgresguide.com
# begin getting emilbayes/secure-password
# begin getting speric/kindle-highlights
# begin getting postcss/postcss-bem-linter
# begin getting thewei/react-native-store
# begin getting lvming6816077/LMVideoTest
# begin getting mdubourg001/glci
# begin getting lionsharecapital/lionshare-desktop
# begin getting JasonHHouse/gaps
# begin getting phpclassic/php-shopify
# begin getting AlexAltea/unicorn.js
# begin getting pimoroni/inky
# begin getting 0xairdropfarmer/medium-clone-on-node
# begin getting qtile/qtile-examples
# begin getting riscv-software-src/riscv-pk
# begin getting tidymodels/parsnip
# begin getting andreafioraldi/frida-fuzzer
# begin getting laCour/slack-night-mode
# begin getting implus/GFocal
# begin getting nathco/Generate-GIF
# begin getting binarylogic/authlogic_example
# begin getting vuetwo/vuetron
# begin getting googlecreativelab/Sprayscape
# begin getting poteto/elixirconf-2016
# begin getting briancollins/BCTabBarController
# begin getting FaridSafi/react-native-basketball
# begin getting zhaomenghuan/mui-demo
# begin getting kreeben/resin
# begin getting ldarren/QuickJS
# begin getting takeoutweight/clojure-scheme
# begin getting aker-gateway/Aker
# begin getting thblt/write-yourself-a-git
# begin getting iNavFlight/inav-configurator
# begin getting sapegin/shipit
# begin getting interactive-matter/aJson
# begin getting grafijs/grafi
# begin getting kentcdodds/genie
# begin getting Robinlovelace/Creating-maps-in-R
# begin getting openboleto/openboleto
# begin getting adafruit/Adafruit_MQTT_Library
# begin getting faob-dev/folding_cell
# begin getting kingyoPiyo/Pico-10BASE-T
# begin getting JokerJohn/LIO_SAM_6AXIS
# begin getting alexmingoia/purescript-pux
# begin getting zaneCC/AndroidUPnPDemo
# begin getting android-notes/auto-scroll-capture
# begin getting mortberg/cubicaltt
# begin getting twilio/twilio-video.js
# begin getting ryanflorence/async-props
# begin getting ricobeck/KFEpubKit
# begin getting mozilla/ichnaea
# begin getting Trevelopment/MZD-AIO
# begin getting saintplay/vue-swatches
# begin getting iost-official/go-iost
# begin getting intmain/HairPowder
# begin getting Rocketseat/comunidade
# begin getting comp500/quilt-serverside-mods
# begin getting Alvin-Zeng/Awesome-Temporal-Action-Localization
# begin getting podo/awesome-framer
# begin getting aacotroneo/laravel-saml2
# begin getting microsoft/vscode-textmate
# begin getting rotators/Fo1in2
# begin getting dwightjack/vue-types
# begin getting nathom/filetype.nvim
# begin getting Aruelius/cloud189
# begin getting velopert/learning-react
# begin getting greymass/anchor
# begin getting martomo/SublimeTextXdebug
# begin getting confuser/graphql-constraint-directive
# begin getting dxa4481/WPA2-HalfHandshake-Crack
# begin getting igorm84/spotify-astro-transitions
# begin getting Netflix/edda
# begin getting NodeArt/angular-commerce
# begin getting naturalatlas/node-gdal
# begin getting OedoSoldier/sd-webui-image-sequence-toolkit
# begin getting stamen/modestmaps-js
# begin getting dapphp/securimage
# begin getting clowwindy/shadowsocks-libev
# begin getting n0bel/PiClock
# begin getting xamarin/docs-archive
# begin getting vita-epfl/CrowdNav
# begin getting thquinn/DraggableGridView
# begin getting cnjackchen/my-chrome
# begin getting JohnEarnest/Mako
# begin getting MscrmTools/XrmToolBox
# begin getting incu6us/goimports-reviser
# begin getting IBM/spring-boot-microservices-on-kubernetes
# begin getting PhantomInsights/baby-names-analysis
# begin getting kmkz/Pentesting
# begin getting stripe-archive/safesql
# begin getting andreasbovens/understanding-viewport
# begin getting linkedin/LayoutTest-iOS
# begin getting xjdrew/gotunnel
# begin getting Pizzabelly/EasyRP
# begin getting BoyCook/TwitterJSClient
# begin getting apertureless/vue-password-strength-meter
# begin getting inkooboo/thread-pool-cpp
# begin getting stefanprodan/k8s-prom-hpa
# begin getting andremm/typedlua
# begin getting WhiteHouse/fb_messenger_bot
# begin getting Chrisvin/RubberPicker
# begin getting fabiomsr/from-java-to-kotlin
# begin getting akshay2211/MusicWave
# begin getting bogerchan/Nier-Visualizer
# begin getting kritzikratzi/Oscilloscope
# begin getting Baidu-AIP/java-sdk
# begin getting maciejhirsz/json-rust
# begin getting josdirksen/learning-threejs-third
# begin getting browserify/brfs
# begin getting cfzd/Ultra-Fast-Lane-Detection-v2
# begin getting lpty/nlp_base
# begin getting tlswg/tls13-spec
# begin getting nefelim4ag/Ananicy
# begin getting envault/envault
# begin getting openlookeng/hetu-core
# begin getting FDA/openfda
# begin getting danielwelch/hassio-zigbee2mqtt
# begin getting linux-sunxi/sunxi-tools
# begin getting avioli/uni_links
# begin getting antoniogarrote/rdfstore-js
# begin getting nusmodifications/nusmods
# begin getting alfa-laboratory/arui-feather
# begin getting hjwdzh/ManifoldPlus
# begin getting pallets-eco/flask-jwt
# begin getting kswedberg/jquery-tmbundle
# begin getting lovezzzxxx/liverecord
# begin getting Evernote/evernote-sdk-js
# begin getting itsbonczek/kingpin
# begin getting gjaldon/ecto_enum
# begin getting kswedberg/jquery-tmbundle
# begin getting lovezzzxxx/liverecord
# begin getting Evernote/evernote-sdk-js
# begin getting MishaLaskin/curl
# begin getting ConsenSys-Academy/Blockchain-Developer-Bootcamp
# begin getting MolecularAI/aizynthfinder
# begin getting TaoRuijie/ECAPA-TDNN
# begin getting LinkedInAttic/cleo
# begin getting xoxco/breakpoints
# begin getting chadaustin/sajson
# begin getting IVMachiavelli/OSINT_Team_Links
# begin getting marshall/logcat-color
# begin getting FasterXML/jackson-dataformat-xml
# begin getting featurist/coypu
# begin getting VFansss/mgs2-v-s-fix
# begin getting jazzband/django-admin-sortable
# begin getting zhangshuiyong/nodequant
# begin getting realm/SwiftCov
# begin getting ksvc/KSYMediaPlayer_iOS
# begin getting ramonhagenaars/nptyping
# begin getting ymgd/codereader
# begin getting onmyway133/EasyConfetti
# begin getting crosbymichael/slex
# begin getting metaskills/less-rails-bootstrap
# begin getting xsc/lein-ancient
# begin getting mcrovero/rubber
# begin getting mozilla/positron
# begin getting stepchowfun/typical
# begin getting tc39/proposal-bigint
# begin getting cherokee/webserver
# begin getting DataXujing/YOLOv8
# begin getting LendingHome/zero_downtime_migrations
# begin getting RobbieHan/gistandard
# begin getting thewhitetulip/Tasks
# begin getting dobarkod/django-queryinspect
# begin getting husky-dev/SAMultisectorControl
# begin getting dodie/vim-disapprove-deep-indentation
# begin getting facebookresearch/OctConv
# begin getting apicollective/apibuilder
# begin getting sastraxi/pgsh
# begin getting MarvinTeichmann/ConvCRF
# begin getting chrismiles/DynamicXray
# begin getting tcort/markdown-link-check
# begin getting dmroeder/pylogix
# begin getting sebastiencs/company-box
# begin getting ZupIT/ritchie-cli
# begin getting diwu/DWURecyclingAlert
# begin getting kadirahq/fast-render
# begin getting MosheBerman/MBCalendarKit
# begin getting alexcorvi/anchorme.js
# begin getting WordPress/dashicons
# begin getting spatie/string
# begin getting Kink3d/kMirrors
# begin getting sindresorhus/jshint-stylish
# begin getting mrdulin/blog
# begin getting Carbs0126/ExpandableTextView
# begin getting SteffeyDev/react-native-popover-view
# begin getting Colt/YelpCamp
# begin getting AttackXiaoJinJin/reactExplain
# begin getting confucianzuoyuan/bookstore
# begin getting Xerios/ScreenManager
# begin getting govizlora/optical-breacher
# begin getting arturdm/jacoco-android-gradle-plugin
# begin getting gamaral/rpi-buildroot
# begin getting the-teacher/the_sortable_tree
# begin getting percona/PerconaFT
# begin getting atom/tree-view
# begin getting theotherp/nzbhydra
# begin getting pwnall/node-open
# begin getting ember-cli-deploy/ember-cli-deploy
# begin getting watson-developer-cloud/personality-insights-nodejs
# begin getting ajoslin/angular-promise-tracker
# begin getting ryanflorence/example-react-router-server-rendering-lazy-routes
# begin getting relay-tools/react-router-relay
# begin getting sunng87/node-geohash
# begin getting ahmedfgad/NumPyCNN
# begin getting ChristianUlbrich/awesome-microfrontends
# begin getting Jaykul/PowerLine
# begin getting turtle0x1/LxdMosaic
# begin getting itsjavi/fontawesome-iconpicker
# begin getting tpope/heroku-fucking-console
# begin getting bahmutov/next-update
# begin getting tunabrain/tantalum
# begin getting kartik-v/yii2-widgets
# begin getting lukeed/regexparam
# begin getting barsoom/attr_extras
# begin getting headllines/hackernews-daily
# begin getting anasfik/flutter-spy
# begin getting ceccopierangiolieugenio/pyTermTk
# begin getting maxdev1/ghost
# begin getting kaixueio/kaixue-docs
# begin getting alskipp/ASScreenRecorder
# begin getting ignacio-rocco/detectorch
# begin getting flipace/lovli.js
# begin getting cloudkj/layer
# begin getting Eilonh/s3crets_scanner
# begin getting bluebird75/luaunit
# begin getting closeio/ciso8601
# begin getting VcDevel/std-simd
# begin getting G4lile0/Heimdall-WiFi-Radar
# begin getting concretecms/concrete5-legacy
# begin getting calderajs/caldera-react
# begin getting itsbonczek/kingpin
# begin getting gjaldon/ecto_enum
# begin getting vgsatorras/few-shot-gnn
# begin getting cenkai88/vue-svg-icon
# begin getting nylas/nylas-perftools
# begin getting pallets-eco/flask-jwt
# begin getting mdipierro/workflow
# begin getting lookingstars/nuomi
# begin getting aws-samples/amazon-personalize-samples
# begin getting tj/serve
# begin getting taivop/awesome-data-annotation
# begin getting MobSF/mobsfscan
# begin getting LetsDefend/awesome-soc-analyst
# begin getting eslint/config-inspector
# begin getting lorenzofiamingo/swiftui-cached-async-image
# begin getting tal-tech/fend
# begin getting GoVanguard/list-infosec-encyclopedia
# begin getting 19wu/19wu
# begin getting rplevy/swiss-arrows
# begin getting martinruenz/maskfusion
# begin getting kswedberg/jquery-tmbundle
# begin getting LinkedInAttic/cleo
# begin getting xoxco/breakpoints
# begin getting chadaustin/sajson
# begin getting IVMachiavelli/OSINT_Team_Links
# begin getting marshall/logcat-color
# begin getting lixi5338619/lxBook
# begin getting shree1999/Data-Structures-and-Algorithms
# begin getting TooTallNate/plist.js
# begin getting victoryhb/streamlit-option-menu
# begin getting scrollback/scrollback
# begin getting FasterXML/jackson-dataformat-xml
# begin getting featurist/coypu
# begin getting pmiaowu/HostCollision
# begin getting btcpayserver/btcpayserver-docker
# begin getting Rufus31415/Simple-WebXR-Unity
# begin getting ccsb-scripps/AutoDock-Vina
# begin getting digitalinnovationone/js-developer-pokedex
# begin getting realm/SwiftCov
# begin getting rustwasm/rust-webpack-template
# begin getting ymgd/codereader
# begin getting smartcontracts/ethereum-book
# begin getting sjr7/seckill
# begin getting lwjglgamedev/lwjglbook-leg
# begin getting bhamrick/multitwitch
# begin getting s0md3v/goop
# begin getting remix-pwa/remix-pwa
# begin getting N0rz3/Zehef
# begin getting ncase/joy
# begin getting open-nomie/nomie5
# begin getting dirkvranckaert/AndroidDecompiler
# begin getting getsentry/raven-go
# begin getting lookfirst/sardine
# begin getting AugustRush/ARAnimation
# begin getting onmyway133/EasyConfetti
# begin getting crosbymichael/slex
# begin getting akd-io/create-next-stack
# begin getting gilmarsquinelato/i18n-manager
# begin getting wh200720041/iscloam
# begin getting GantMan/jail-monkey
# begin getting metaskills/less-rails-bootstrap
# begin getting LendingHome/zero_downtime_migrations
# begin getting RobbieHan/gistandard
# begin getting thewhitetulip/Tasks
# begin getting dobarkod/django-queryinspect
# begin getting PacktPublishing/TensorFlow-Machine-Learning-Cookbook
# begin getting eleurent/rl-agents
# begin getting ihaolin/antares
# begin getting graalvm/graalvm-demos
# begin getting GSA/data.gov
# begin getting bignerdranch/CoreDataStack
# begin getting laurihy/angular-payments
# begin getting dodie/vim-disapprove-deep-indentation
# begin getting facebookresearch/OctConv
# begin getting apicollective/apibuilder
# begin getting sastraxi/pgsh
# begin getting MarvinTeichmann/ConvCRF
# begin getting Netflix/blitz4j
# begin getting stuhli/awesome-event-ids
# begin getting status-im/nimbus-eth1
# begin getting flschweiger/reply
# begin getting ccwav/QLScript2
# begin getting ZupIT/ritchie-cli
# begin getting duolatech/xapimanager
# begin getting lammertb/libcrc
# begin getting n0shake/clocker
# begin getting jenkinsci/pipeline-model-definition-plugin
# begin getting Polish-Miko/GravityEngine
# begin getting patricktalmadge/bootstrapper
# begin getting session-replay-tools/tcpburn
# begin getting kadirahq/fast-render
# begin getting MosheBerman/MBCalendarKit
# begin getting alexcorvi/anchorme.js
# begin getting WordPress/dashicons
# begin getting chenxin-dlut/TransT
# begin getting susam/muboard
# begin getting TheLarkInn/webpack-workshop-2018
# begin getting tsl0922/ImPlay
# begin getting BartoszMilewski/Okasaki
# begin getting jdantonio/functional-ruby
# begin getting calebhearth/formulaic
# begin getting get-eventually/eventually-rs
# begin getting 13812851221/-rxrw-daily_morning
# begin getting myndzi/wtfnode
# begin getting dhruvasagar/vim-dotoo
# begin getting longcw/RoIAlign.pytorch
# begin getting preshing/turf
# begin getting jonathanslenders/asyncio-redis
# begin getting jupiterjs/jquerymx
# begin getting rmm5t/strip_attributes
# begin getting pandolia/easy-service
# begin getting JDAI-CV/centerX
# begin getting anthonya1999/GoodNight
# begin getting mapbox/mapnik-vector-tile
# begin getting martinwells/objects.js
# begin getting hortonworks-spark/shc
# begin getting kharvd/gpt-cli
# begin getting bab2min/tomotopy
# begin getting stakewithus/defi-by-example
# begin getting leemeichin/say-cheese
# begin getting SINTEF-9012/PruneCluster
# begin getting justjavac/1s
# begin getting googlearchive/android-viewpager2
# begin getting mamaral/MAThemeKit
# begin getting movehand/raisr
# begin getting ja9er/Gofreeproxy
# begin getting rspivak/slimit
# begin getting yatish27/linkedin-scraper
# begin getting chibicode/TypeScript-for-Beginner-Programmers
# begin getting fengzhizi715/ProxyPool
# begin getting chernivtsijs/made-in-ukraine
# begin getting auth0/SimpleKeychain
# begin getting Accenture/jenkins-attack-framework
# begin getting coredns/deployment
# begin getting minooo/React-Study
# begin getting mbrochh/vim-as-a-python-ide
# begin getting drakeet/Floo
# begin getting laravel/nova-issues
# begin getting thulab/DeepHash
# begin getting uber-research/go-explore
# begin getting chef-boneyard/vagrant-omnibus
# begin getting Mochengvia/PanuonUI
# begin getting peterkeen/dokuen
# begin getting boycechang/BCMagicTransition
# begin getting maxwells/bootstrap-tags
# begin getting Paper99/SRFBN_CVPR19
# begin getting yipengmu/react-native-android-lession
# begin getting TakeScoop/SwiftyButton
# begin getting MCGallaspy/dr_strangetemplate
# begin getting tomsoft1/StackBluriOS
# begin getting mthbernardes/rsg
# begin getting starburst1977/readium
# begin getting g0tmi1k/os-scripts
# begin getting liuhuanyong/ChainKnowledgeGraph
# begin getting RelevanceAI/vectorhub
# begin getting automateyournetwork/automate_your_network
# begin getting wpengine/frost
# begin getting rnevius/minimal-django
# begin getting heroku/heroku-accounts
# begin getting ENFOS/FlowupLabels.js
# begin getting onedayitwillmake/RealtimeMultiplayerNodeJs
# begin getting astrails/dotvim
# begin getting emailjs/emailjs-imap-client
# begin getting rbignon/doctoshotgun
# begin getting okdalto/VisualizeMNIST
# begin getting mariusae/trickle
# begin getting it-rico/ZrcListView
# begin getting drewblas/aws-ses
# begin getting sstephenson/global_phone
# begin getting briis/unifiprotect
# begin getting blockchain-jd-com/jdchain
# begin getting lucasr/probe
# begin getting dixonzhao/Basic_Study
# begin getting brentvatne/react-native-animated-demo-tinder
# begin getting Spikef/react-native-gesture-password
# begin getting glenyi/FloatRatingView
# begin getting kogakure/gitweb-theme
# begin getting langhsu/mblog
# begin getting 373675032/moti-cloud
# begin getting google/webauthndemo
# begin getting Kilian/f.lux-indicator-applet
# begin getting airlift/aircompressor
# begin getting makeomatic/redux-connect
# begin getting hecomi/uREPL
# begin getting jlondiche/job-board-php
# begin getting r-spatial/stars
# begin getting hprose/hprose-java
# begin getting slashdotdash/jekyll-lunr-js-search
# begin getting DONGChuan/Yummy-Jekyll
# begin getting bportaluri/WiFiEsp
# begin getting jessfraz/gmailfilters
# begin getting aceisScope/WaterflowView
# begin getting iitzco/faced
# begin getting santinic/pampy.js
# begin getting tkf/emacs-ipython-notebook
# begin getting marcj/jquery-selectBox
# begin getting Tencent/Fanvas
# begin getting prooph/event-store
# begin getting ilovepose/DarkPose
# begin getting aozora/bootplus
# begin getting krzysztofzablocki/crafter
# begin getting lukeed/dimport
# begin getting yyx990803/launch-editor
# begin getting ecomfe/edp
# begin getting 1buran/rHttp
# begin getting reactiveui/Camelotia
# begin getting 252860883/ArtQRCode
# begin getting leverdeterre/JMHoledView
# begin getting petehunt/react-boilerplate
# begin getting alexkuz/react-dock
# begin getting Tatamo/atcoder-cli
# begin getting padolsey-archive/jquery.lint--old
# begin getting underdash/underdash
# begin getting RamWire/NinaPagerView
# begin getting blockloop/scan
# begin getting flutter/games
# begin getting john30/ebusd
# begin getting jDataView/jDataView
# begin getting malsup/corner
# begin getting larsonjj/generator-yeogurt
# begin getting colinmorris/SongSim
# begin getting webark/ember-component-css
# begin getting dg/twitter-php
# begin getting SmartDengg/RxBlur
# begin getting LinkedDestiny/swoole-src-analysis
# begin getting zedshaw/python-lust
# begin getting sgolivernet/curso-android-src
# begin getting dvdzkwsk/react-reformed
# begin getting karma-runner/karma-jasmine
# begin getting thubbo/awesome-dubbo
# begin getting orta/pragmatic-testing
# begin getting cseagle/sk3wldbg
# begin getting jremmen/vim-ripgrep
# begin getting UPC/ravada
# begin getting n8/multi_fetch_fragments
# begin getting kaievns/ruby-fighter
# begin getting microsoft/thrifty
# begin getting drizzt/vps2arch
# begin getting CooperRS/RMActionController
# begin getting CodeSleeve/stapler
# begin getting partiql/partiql-lang-kotlin
# begin getting elixir-ecto/ecto_sql
# begin getting jekyc/wig
# begin getting mixitconf/mixit
# begin getting bennett-treptow/laravel-migration-generator
# begin getting cyberdefenders/DetectionLabELK
# begin getting stressapptest/stressapptest
# begin getting OpenBMB/BMTrain
# begin getting TylerBarnes/gatsby-plugin-transition-link
# begin getting kennethkalmer/daemon-kit
# begin getting nonamecoder/FlipperZeroHondaFirmware
# begin getting ethz-asl/robust_point_cloud_registration
# begin getting Doist/todoist-python
# begin getting mlouielu/cn_constitution_2018
# begin getting Bossyao168/StackOverView
# begin getting huannan/XArch
# begin getting simonepri/upash
# begin getting mahemoff/chrome-boilerplate
# begin getting hellogcc/100-gcc-tips
# begin getting guangqiang-liu/mpvue-meituan
# begin getting lucaong/cubdb
# begin getting chef/chef-zero
# begin getting omgmog/uxofvr.com
# begin getting liguigui/CyC2018-CS-Notes
# begin getting kubernetes-retired/kubernetes-anywhere
# begin getting jadell/neo4jphp
# begin getting nathanl/searchlight
# begin getting TomLingham/Laravel-Searchy
# begin getting willfarrell/alfred-encode-decode-workflow
# begin getting ma-xu/Context-Cluster
# begin getting vueComponent/pro-components
# begin getting ampl/gsl
# begin getting whitesock/open-replicator
# begin getting cmaddux/littlebox
# begin getting snickers/snickers
# begin getting shurcooL-legacy/Conception
# begin getting YoshitakaMo/localcolabfold
# begin getting dropbox/pyxl
# begin getting RikkaApps/WADB
# begin getting PQClean/PQClean
# begin getting d4rkr00t/whybundled
# begin getting zond/god
# begin getting bingdian/waterfall
# begin getting JohnSundell/Sweep
# begin getting liuchuo/LeetCode
# begin getting wix-incubator/accord
# begin getting mitsuhiko/python-modernize
# begin getting ircmaxell/PhpGenerics
# begin getting cs0x7f/cstimer
# begin getting prouast/heartbeat
# begin getting lucaorio/sketch-styles-generator
# begin getting nick-bai/snake
# begin getting SegoCode/AutoWall
# begin getting igrigorik/node-spdyproxy
# begin getting zhan2046/awaker
# begin getting solo-io/sqoop
# begin getting frhagn/Typewriter
# begin getting dj-nitehawk/MongoDB.Entities
# begin getting kennethkalmer/daemon-kit
# begin getting nonamecoder/FlipperZeroHondaFirmware
# begin getting ethz-asl/robust_point_cloud_registration
# begin getting vmdanilov/TextFlow
# begin getting mlouielu/cn_constitution_2018
# begin getting jonbruner/generative-adversarial-networks
# begin getting timbertson/python-readability
# begin getting SunshowerC/blog
# begin getting kadeessh/kadeessh
# begin getting virtphp/virtphp
# begin getting JedWatson/sydjs-site
# begin getting workshopper/learnyoureact
# begin getting saik0/UnifiedPreference
# begin getting MeCKodo/vue-tap
# begin getting Bossyao168/StackOverView
# begin getting jetify-com/tyson
# begin getting MCUdude/MicroCore
# begin getting tikv/raft-engine
# begin getting huannan/XArch
# begin getting simonepri/upash
# begin getting mahemoff/chrome-boilerplate
# begin getting hellogcc/100-gcc-tips
# begin getting guangqiang-liu/mpvue-meituan
# begin getting lucaong/cubdb
# begin getting flovan/headstart
# begin getting TheRemote/Ubuntu-Server-raspi4-unofficial
# begin getting Androguide/HoloGraphLibrary
# begin getting gonzalezreal/Groot
# begin getting cashapp/AccessibilitySnapshot
# begin getting tobiasahlin/moving-letters
# begin getting CryptoBlades/cryptoblades
# begin getting indieisaconcept/grunt-styleguide
# begin getting lvapeab/nmt-keras
# begin getting vicpinm/Kotlin-Realm-Extensions
# begin getting soroushmehr/sampleRNN_ICLR2017
# begin getting KristianOellegaard/django-hvad
# begin getting kubernetes-retired/kubernetes-anywhere
# begin getting andrewssobral/vehicle_detection_haarcascades
# begin getting BoyuanJiang/Age-Gender-Estimate-TF
# begin getting oconnor663/sha256_project
# begin getting Odyssey-Team/Taurine
# begin getting shaj13/go-guardian
# begin getting etalab/DVF-app
# begin getting voidful/TextRL
# begin getting izy521/discord.io
# begin getting idmillington/aicore
# begin getting b3nj5m1n/kommentary
# begin getting winjs/winstrap
# begin getting kumpulanremaja/wifi
# begin getting markofjohnson/HJCache
# begin getting nathanl/searchlight
# begin getting TomLingham/Laravel-Searchy
# begin getting willfarrell/alfred-encode-decode-workflow
# begin getting ma-xu/Context-Cluster
# begin getting vueComponent/pro-components
# begin getting ampl/gsl
# begin getting cmaddux/littlebox
# begin getting sysdream/hershell
# begin getting notedit/media-server-go
# begin getting kanryu/quickviewer
# begin getting vinceliuice/Layan-gtk-theme
# begin getting bmuschko/gradle-tomcat-plugin
# begin getting icindy/wxSearch
# begin getting kjempelodott/rickify
# begin getting vmware-archive/dispatch
# begin getting YoshitakaMo/localcolabfold
# begin getting dropbox/pyxl
# begin getting RikkaApps/WADB
# begin getting PQClean/PQClean
# begin getting d4rkr00t/whybundled
# begin getting zond/god
# begin getting headwindz/headwindz.run
# begin getting maxkonovalov/MKDropdownMenu
# begin getting FGRibreau/spinners
# begin getting SysSn13/leetcode-rating-predictor
# begin getting IndicoDataSolutions/Passage
# begin getting jacklam718/react-native-button-component
# begin getting mitsuhiko/python-modernize
# begin getting ircmaxell/PhpGenerics
# begin getting cs0x7f/cstimer
# begin getting prouast/heartbeat
# begin getting atom-archive/electron-starter
# begin getting kpot/keras-transformer
# begin getting sfackler/cargo-tree
# begin getting tonisalae/TSMiniWebBrowser
# begin getting nick-bai/snake
# begin getting SegoCode/AutoWall
# begin getting igrigorik/node-spdyproxy
# begin getting codrops/AnimatedSVGIcons
# begin getting marshallino16/Demo-FloatingView
# begin getting respondcreate/django-versatileimagefield
# begin getting norman/babosa
# begin getting cjl3080434008/2014
# begin getting weiwang3056/baota_release
# begin getting kmagiera/babel-watch
# begin getting staffantan/unityglitch
# begin getting uber/signals-ios
# begin getting sqs/goreturns
# begin getting mgechev/guess-next
# begin getting hwwang55/GraphGAN
# begin getting CoocooFroggy/FutureRestore-GUI
# begin getting Rookie-Birds/Fabric-Tutorial_zh-CN
# begin getting edwingeng/wuid
# begin getting nicothin/idiomatic-pre-CSS
# begin getting thunks/thunks
# begin getting jupyter/tmpnb
# begin getting mattt/rack-scaffold
# begin getting anko/eslisp
# begin getting MicrocontrollersAndMore/OpenCV_3_License_Plate_Recognition_Python
# begin getting larryhastings/gilectomy
# begin getting wangzuo/input-moment
# begin getting indrimuska/angular-moment-picker
# begin getting crcn/paperclip.js
# begin getting brunogaspar/laravel-starter-kit
# begin getting alibaba/gym-starcraft
# begin getting codebuddies/codebuddies
# begin getting Iku/Google-Forms-to-Discord
# begin getting sdgmf/go-project-sample
# begin getting chiuwingyan/house
# begin getting CheckPointSW/InviZzzible
# begin getting paradigmxyz/paradigm-ctf-2021
# begin getting ebryn/ember-model
# begin getting wakatime/sublime-wakatime
# begin getting ericjang/draw
# begin getting lbrndnr/LBYouTubeView
# begin getting maccman/stylo
# begin getting YousefED/ElasticUI
# begin getting fullstackhero/blazor-wasm-boilerplate
# begin getting jwilling/JNWCollectionView
# begin getting oliyh/martian
# begin getting soulteary/docker-llama2-chat
# begin getting timschreiber/DapperUnitOfWork
# begin getting kabouzeid/nvim-lspinstall
# begin getting udibr/headlines
# begin getting Rythe-Interactive/Rythe-Engine
# begin getting bep/s3deploy
# begin getting abiaad/PAAImageView
# begin getting hokein/Wiki
# begin getting gitskarios/Gitskarios
# begin getting xebia-functional/macroid
# begin getting chenzeyu/CZPicker
# begin getting stefanceriu/SCStringsUtility
# begin getting matthewpalmer/Charter
# begin getting kevinlin311tw/caffe-cvprw15
# begin getting sindresorhus/serialize-error
# begin getting spiritualized1997/openFPGA-GB-GBC
# begin getting skorokithakis/expounder
# begin getting wesovilabs/koazee
# begin getting bluwy/whyframe
# begin getting CleverProgrammers/spotify-clone
# begin getting raspberrypi/picotool
# begin getting misakuo/svgtoandroid
# begin getting Ricbet/panel-magic
# begin getting OffensivePython/Nscan
# begin getting kayan1990/ShareButton
# begin getting lingochamp/QiniuImageLoader
# begin getting keijiro/UnitySkyboxShaders
# begin getting mblondel/soft-dtw
# begin getting zint/zint-gpl-only
# begin getting ehynds/jquery-notify
# begin getting skyfe79/SwiftImageProcessing
# begin getting CoderLNHui/SourceCodeAnalysis
# begin getting geniuscarrier/webpack-boilerplate
# begin getting markdalgleish/fathom
# begin getting osuushi/Smooth.js
# begin getting tj/pomo
# begin getting hongyangAndroid/Android-ProgressBarWidthNumber
# begin getting TheLarkInn/artsy-webpack-tour
# begin getting boredream/BorePlugin
# begin getting kirbysayshi/vash
# begin getting 8enet/AppOpsX
# begin getting okdroid/checkable-chip-view
# begin getting abe33/atom-pigments
# begin getting ceabie/DexKnifePlugin
# begin getting jiasenlu/NeuralBabyTalk
# begin getting kickingvegas/YmsCoreBluetooth
# begin getting obendidi/Tracking-with-darkflow
# begin getting rsms/sol
# begin getting varvet/serenade.js
# begin getting miickel/gulp-angular-templatecache
# begin getting halvardssm/deno-nessie
# begin getting jez/pandoc-starter
# begin getting chrislusf/teeproxy
# begin getting FrictionalGames/PenumbraOverture
# begin getting dmitry-zaitsev/AndroidSideMenu
# begin getting klaudiosinani/moviebox
# begin getting gopro/gpmf-parser
# begin getting poweradminllc/PAExec
# begin getting craftcms/awesome
# begin getting ustbhuangyi/lyric-parser
# begin getting THU-KEG/Entity_Alignment_Papers
# begin getting chef-boneyard/chef-provisioning
# begin getting remarkjs/remark-react
# begin getting mrjoes/tornadio2
# begin getting euvl/v-clipboard
# begin getting cheeaun/puppetron
# begin getting arsham/figurine
# begin getting ironsmile/euterpe
# begin getting pengzhiliang/Conformer
# begin getting kevinschoon/pomo
# begin getting ellioman/ShaderProject
# begin getting jondot/rn-snoopy
# begin getting ChrisTruncer/PenTestScripts
# begin getting csstools/system-font-css
# begin getting joeblau/FlappyBlock
# begin getting expo/ex-navigator
# begin getting yabhq/laravel-scout-mysql-driver
# begin getting doxout/recluster
# begin getting remarshal-project/remarshal
# begin getting djyde/ToProgress
# begin getting cd-dongzi/vue-project
# begin getting meetmore/lottery.js
# begin getting GoogleChrome/OriginTrials
# begin getting leanlabsio/kanban
# begin getting terkelg/zet
# begin getting odavid/typeorm-transactional-cls-hooked
# begin getting HeinrichApfelmus/reactive-banana
# begin getting peplin/pygatt
# begin getting ngraziano/SharpRTSP
# begin getting knownsec/ZoomEye-python
# begin getting izacus/RoboGif
# begin getting Subito-it/Masaccio
# begin getting sebastianbergmann/php-jenkins-template
# begin getting a1ive/grub2-filemanager
# begin getting dotnetcore/aspnetcore-doc-cn
# begin getting ipenywis/react-solid
# begin getting DanielRapp/fragment.js
# begin getting microsoft/Mesh-processing-library
# begin getting emmabostian/fem-design-systems
# begin getting no-stack-dub-sack/cs-playground-react
# ...
# begin getting cn2t/doubi-SSR
# begin getting scalingexcellence/scrapybook
# begin getting nikitavoloboev/alfred-my-mind
# begin getting UDST/urbansim
# begin getting Murzchnvok/rofi-collection
# begin getting wilsonzlin/edgesearch
# begin getting wojciech-graj/doom-ascii
# begin getting dyn4j/dyn4j
# begin getting gruntjs/grunt-contrib
# begin getting jberkel/android-plugin
# begin getting PUGX/badge-poser
# begin getting devendroid/SquareMenu
# begin getting jakob/Postico
# begin getting platformio/platformio-atom-ide
# begin getting esap/wechat
# begin getting shaopx/VideoClipEditViewTest
# begin getting WAMAWAMA/TNSCUI2020-Seg-Rank1st
# begin getting tejado/Authorizer
# begin getting gavinwahl/postgres-json-schema
# begin getting pmndrs/ecctrl
# begin getting AIChallenger/AI_Challenger_2017
# begin getting robrix/RXCollections
# begin getting madhu-sagar/system-design-react-code-examples
# begin getting keymetrics/docker-pm2
# begin getting tinystacks/precloud
# begin getting dxxzst/OfflineMap
# begin getting sybrenstuvel/python-rsa
# begin getting bryandlee/FreezeG
# begin getting davidliwei/awesome-CRISPR
# begin getting safe6Sec/PentestNote
# begin getting askides/react-plock
# begin getting horizon3ai/vcenter_saml_login
# begin getting trickster0/TartarusGate
# begin getting skydoves/ColorPickerPreference
# begin getting oxc-project/javascript-parser-in-rust
# begin getting prathimacode-hub/ML-ProjectKart
# begin getting ibireme/YYDispatchQueuePool
# begin getting egoist/vue-client-only
# begin getting rustd/AspnetIdentitySample
# begin getting roam-unofficial/roam-toolkit
# begin getting mozilla/zamboni
# begin getting m90/seeThru
# begin getting sml2h3/mmewmd_crack_for_wenshu
# begin getting roclark/sportsipy
# begin getting letianzj/quanttrader
# begin getting itsmehacker/CardPwn
# begin getting TinyMPC/TinyMPC
# begin getting w4mxl/V2LF
# begin getting chinedufn/webgl-water-tutorial
# begin getting keremciu/font-bundles
# begin getting bradfitz/embiggen-disk
# begin getting mobxjs/mobx-vue
# begin getting Azure/Azure-DataFactory
# begin getting sreyafrancis/PFNN
# begin getting bdebon/choiceof.dev
# begin getting 710leo/ZVulDrill
# begin getting Sephiroth87/Crayons
# begin getting cmer/gigabyte-z390-aorus-master-hackintosh
# begin getting pulp-platform/pulp-dronet
# begin getting hjacobs/kube-janitor
# begin getting necolas/css3-social-signin-buttons
# begin getting EnvelopSound/EnvelopForLive
# begin getting AlexeySoshin/smali2java
# begin getting nudibranchrecords/hedron
# begin getting ankanbhunia/PIDM
# begin getting lecepin/douyin-downloader
# begin getting 10play/10tap-editor
# begin getting pfalcon/awesome-smarthome
# begin getting sane/sane
# begin getting nslogx/weapp-poem
# begin getting vatro/svelthree
# begin getting grepplabs/kafka-proxy
# begin getting balacode/one-file-pdf
# begin getting forscht/ddrive
# begin getting hallatore/stable-diffusion-webui-chatgpt-utilities
# begin getting gfoss/PSRecon
# begin getting RobotsAndPencils/buford
# begin getting dekuNukem/FAP80
# begin getting mhausenblas/cinf
# begin getting chokcoco/httphijack
# begin getting Al4ise/Azule
# begin getting skb1129/react-native-change-icon
# begin getting sunnweiwei/RankGPT
# begin getting lmsqueezy/laravel
# begin getting TeamWin/twrpme
# begin getting laracasts/Integrated
# begin getting lo-th/phy
# begin getting autumnai/collenchyma
# begin getting alexballas/go2tv
# begin getting timctho/VNect-tensorflow
# begin getting infinit/elle
# begin getting axe-api/axe-api
# begin getting react-component/queue-anim
# begin getting nxengine/nxengine-evo
# begin getting diederikdehaas/rtl8812AU
# begin getting dome272/Instagram-DeepFake-Bot
# begin getting brave/brave-ui
# begin getting qiniu/iconv
# begin getting sachinkesiraju/SKSplashView
# begin getting Carbs0126/AvatarImageView
# begin getting DenTelezhkin/ZoomInteractiveTransition
# begin getting jeresig/node-stream-playground
# begin getting codediodeio/geofirex
# begin getting dmsurti/AssimpKit
# begin getting ivito/cookbook
# begin getting Hyde46/hoard
# begin getting Androxyde/Flashtool
# begin getting igorbrigadir/awesome-twitter-algo
# begin getting flipperdevices/blackmagic-esp32-s2
# begin getting google-deepmind/dsprites-dataset
# begin getting TeehanLax/UICollectionView-Spring-Demo
# begin getting leanote/leanote-ios
# begin getting line/stellite
# begin getting nettitude/SharpSocks
# begin getting PWA-POLICE/pwa-bugs
# begin getting paulcollett/vue-masonry-css
# begin getting huajh/awesome-latex-cv
# begin getting HMY314/NineGridLayout
# begin getting acado/acado
# begin getting nepluno/libwetcloth
# begin getting ankane/hightop
# begin getting DropEdge/DropEdge
# begin getting Sense-X/X-Temporal
# begin getting jonleighton/focused_controller
# begin getting starling/starling
# begin getting incrediblesound/story-graph
# begin getting facebookarchive/flow-remove-types
# begin getting Frank-Zhu/TriangleRectangleLabelView
# begin getting KonradIT/autoexechack
# begin getting evilbinary/scheme-lib
# begin getting boai/BABaseProject
# begin getting fluent/fluent-bit-kubernetes-logging
# begin getting amol-mandhane/htmlPy
# begin getting ShuoYang-1998/Few_Shot_Distribution_Calibration
# begin getting PaulUithol/backbone-tastypie
# begin getting passsy/kt.dart
# begin getting dangeabunea/RomanianCoderExamples
# begin getting AlexTheAnalyst/AlexTheAnalyst
# begin getting asaotomo/FofaMap
# begin getting xunholy/k8s-gitops
# begin getting linode/cli
# begin getting antoine77340/Youtube-8M-WILLOW
# begin getting HeroicCybersecurity/Whitepaper
# begin getting dwzteam/dwz_jui
# begin getting MrMEEE/bumblebee-Old-and-abbandoned
# begin getting Path-Check/safeplaces-dct-app
# begin getting bighuang624/Time-Series-Papers
# begin getting croath/UIImageView-BetterFace-Swift
# begin getting GooGee/Entity-Builder
# begin getting capless/warrant
# begin getting thaerkh/vim-workspace
# begin getting jckuester/awsweeper
# begin getting devernay/xcodelegacy
# begin getting traceo-dev/traceo
# begin getting 137-rick/Dora-RPC
# begin getting macournoyer/tinyrb
# begin getting lmthang/thesis
# begin getting swimlane/pyattck
# begin getting jsonwebtoken/jsonwebtoken.github.io
# begin getting systemjs/builder
# begin getting aminography/PrimeDatePicker
# begin getting zce/api-proxy
# begin getting jeremyevans/home_run
# begin getting malte-wessel/react-textfit
# begin getting gan74/Yave
# begin getting vuejs/vue-hot-reload-api
# begin getting ierror/ssh-permit-a38
# begin getting baseprime/grapnel
# begin getting chenqihui/NewsFourApp
# begin getting canpool/qtcanpool
# begin getting abhijithvijayan/stargazed
# begin getting ccoenraets/directory-backbone-bootstrap
# begin getting emberjs/list-view
# begin getting WXGBridgeQ/SwiftPullToRefresh
# begin getting udacity/sagemaker-deployment
# begin getting nekonora/TaggerKit
# begin getting troylelandshields/omgrpc
# begin getting EternalWraith/PalEdit
# begin getting delfrrr/npm-consider
# begin getting mrmartineau/SublimeTextSetupWiki
# begin getting exinnet/tclip
# begin getting nokonoko/Pomf
# begin getting pavlov99/json-rpc
# begin getting pakastin/car
# begin getting uncomplicate/fluokitten
# begin getting tabalinas/jssocials
# begin getting Hardtack/HTProgressHUD
# begin getting mengxiangyue/The-Swift-2.0-Programming-Language-playground
# begin getting LinkedInAttic/inject
# begin getting alcaeus/mongo-php-adapter
# begin getting simonsmh/notocjk
# begin getting WithSecureLabs/leonidas
# begin getting jbd/msrsync
# begin getting true-grue/Compiler-Development
# begin getting webrtc/KITE
# begin getting bradcornford/Googlmapper
# begin getting facebookarchive/doh-proxy
# begin getting Markakd/CVE-2022-2588
# begin getting tomas-gajarsky/facetorch
# begin getting lukeredpath/LRResty
# begin getting spring-attic/spring-scala
# begin getting asamiller/den
# begin getting aloha/laravel-twilio
# begin getting ZwwWayne/K-Net
# begin getting 0cyn/ktool
# begin getting hallettj/jslint.vim
# begin getting matrixxun/ImmersiveDetailSample
# begin getting csswizardry/csswizardry.github.com
# begin getting schreiberstein/lucidagrandeyosemite
# begin getting Yarikx/reductor
# begin getting joxa/joxa
# begin getting tobbelobb/hangprinter
# begin getting philbooth/complexity-report
# begin getting badoualy/datepicker-timeline
# begin getting vmware-archive/haret
# begin getting HarvsG/WireGuardMeshes
# begin getting pierre-lecocq/emacs4developers
# begin getting smartcontractkit/defi-minimal
# begin getting Tastenkunst/brfv4_javascript_examples
# begin getting kaleai/DBinding
# begin getting quora/qmf
# begin getting mirkonasato/jodconverter
# begin getting sacmehta/delight
# begin getting keiohta/tf2rl
# begin getting TryKickoff/kickoff
# begin getting philbooth/complexity-report
# begin getting HarvsG/WireGuardMeshes
# begin getting pierre-lecocq/emacs4developers
# begin getting smartcontractkit/defi-minimal
# begin getting Tastenkunst/brfv4_javascript_examples
# begin getting kaleai/DBinding
# begin getting material-motion/direct
# begin getting voronianski/esnextbin
# begin getting hybridgroup/gabba
# begin getting core-player/vue-core-video-player
# begin getting NVlabs/FAN
# begin getting FriendsOfSymfony/FOSCommentBundle
# begin getting vuejs/vue-animated-list
# begin getting fengjundev/React-Native-Remote-Update
# begin getting erkie/erkie.github.com
# begin getting chrisgrieser/shimmering-focus
# begin getting patrikf/glip
# begin getting bdefore/universal-redux
# begin getting antwarjs/antwar
# begin getting boblauer/mock-require
# begin getting Doctoror/ParticlesDrawable
# begin getting ozanmakes/wring
# begin getting TheThingsArchive/ttn
# begin getting googlearchive/android-dynamic-features
# begin getting chilts/awssum
# begin getting ryanmcdermott/react-native-login
# begin getting wantedly/swift-rss-sample
# begin getting sbakhtiarov/gif-movie-view
# begin getting evilcos/xssor
# begin getting vicwang163/react-to-vue
# begin getting securas/Daemon-vs-Demon
# begin getting criteo-research/reco-gym
# begin getting 385841539/IdentityImageView
# begin getting iostreamer-X/Awkward
# begin getting oliyh/re-graph
# begin getting HCIILAB/SCUT-HEAD-Dataset-Release
# begin getting danger/peril
# begin getting Abizern/xcode-snippets
# begin getting gaearon/react-proxy
# begin getting khiav223577/deep_pluck
# begin getting AngeLouCN/CaraNet
# begin getting alexzaitsev/freepager
# begin getting zhangke3016/ViewSpreadTranslationController
# begin getting Modernizr/grunt-modernizr
# begin getting lingxiaoyi/Taro-navigation-bar
# begin getting BrightstarDB/BrightstarDB
# begin getting cryptonek/widevine-l3-decryptor
# begin getting hartleybrody/fb-messenger-bot
# begin getting simonhf/sharedhashfile
# begin getting Vinum-Security/kubernetes-security-checklist
# begin getting rdbraatz/data-driven-prediction-of-battery-cycle-life-before-capacity-degradation
# begin getting jetheredge/SquishIt
# begin getting allenai/macaw
# begin getting davidmarble/virtualenvwrapper-win
# begin getting cgoldberg/multi-mechanize
# begin getting LoranWong/Android-Code-Style
# begin getting sharish/BitmapMerger
# begin getting roots/roots-example-project.com
# begin getting openchain/openchain
# begin getting Z-yq/TensorflowASR
# begin getting Unity-Technologies/vscode-unity-debug
# begin getting minghe/koa-book
# begin getting geeknam/python-gcm
# begin getting mapleqin/Android-RatioLayout
# begin getting deepsense-ai/roi-pooling
# begin getting romannurik/AndroidSDKSearchExtension
# begin getting Beg-in/vue-babylonjs
# begin getting buildspace/gpt3-writer-starter
# begin getting jlongster/backend-with-webpack
# begin getting gregmuellegger/django-autofixture
# begin getting CadeEvs/FrostyToolsuite
# begin getting naver-ai/DenseDiffusion
# begin getting erikthedeveloper/code-review-emoji-guide
# begin getting adilyalcin/Keshif
# begin getting tpolecat/cats-infographic
# begin getting mvcss/mvcss
# begin getting fnichol/dvm
# begin getting googlearchive/firefeed
# begin getting reaalkhalil/JSRobot
# begin getting akatsuki105/magia
# begin getting schnerd/chrome-headless-screenshots
# begin getting neithernut/git-dit
# begin getting hashlin/rally
# begin getting bilive/bilive_client
# begin getting crodjer/watchman
# begin getting t3rm1n4l/megacmd
# begin getting icerockdev/moko-template
# begin getting CymChad/BRVAHST
# begin getting Abbotton/weapp-snippet-for-sublime-text-2-3
# begin getting max-mapper/linux
# begin getting rescrv/HyperLevelDB
# begin getting unkleho/reactronica
# begin getting kelseyhightower/kubernetes-cluster-federation
# begin getting ascoders/alipay
# begin getting AlexMofer/ProjectX
# begin getting ImangazalievM/CleanArchitectureManifest
# begin getting daimajia/bleed-baidu-white
# begin getting karol-f/ngMario
# begin getting betamaxteam/betamax
# begin getting antoine77340/Youtube-8M-WILLOW
# begin getting HeroicCybersecurity/Whitepaper
# begin getting bighuang624/Time-Series-Papers
# begin getting croath/UIImageView-BetterFace-Swift
# begin getting lazywinadmin/LazyWinAdmin_GUI
# begin getting GloDroid/glodroid_manifest
# begin getting DSchroer/dslcad
# begin getting buttercup/buttercup-core
# begin getting heibaiying/spring-samples-for-all
# begin getting meilisearch/meilisearch-laravel-scout
# begin getting raramuridesign/mysql-country-list
# begin getting kohjingyu/fromage
# begin getting RhinoSecurityLabs/GCPBucketBrute
# begin getting awslabs/aws-servicebroker
# begin getting alexmyczko/fnt
# begin getting alexa-samples/skill-sample-nodejs-audio-player
# begin getting GooGee/Entity-Builder
# begin getting capless/warrant
# begin getting thaerkh/vim-workspace
# begin getting jckuester/awsweeper
# begin getting devernay/xcodelegacy
# begin getting traceo-dev/traceo
# begin getting 137-rick/Dora-RPC
# begin getting bradfrost/gatsby-style-guide-guide
# begin getting iammerrick/Squire.js
# begin getting dpw/kvm-hello-world
# begin getting fsaintjacques/disruptor--
# begin getting qianxiao996/CTF-Tools
# begin getting abhi16180/photon
# begin getting reygonzales/RPJSONValidator
# begin getting fengdai/AlertDialogPro
# begin getting zhnnnnn/ZHNCosmos
# begin getting SQLStreamStore/SQLStreamStore
# begin getting nx-js/framework
# begin getting amitmerchant1990/how-products-got-their-name
# begin getting Aufree/ESTMusicIndicator
# begin getting JakeWharton/salvage
# begin getting ammulder/AppleIntelWiFiMVM
# begin getting microsoft/workbooks
# begin getting pydanny/django-uni-form
# begin getting macournoyer/tinyrb
# begin getting jamsinclair/ballast
# begin getting liip/LiipMonitorBundle
# begin getting shyamseshadri/angularjs-up-and-running
# begin getting mailgun/mailgun-ruby
# begin getting paragonie/chronicle
# begin getting systemjs/builder
# begin getting hexiangnan/neural_factorization_machine
# begin getting toptal/active-job-style-guide
# begin getting Kaixhin/Autoencoders
# begin getting malte-wessel/react-textfit
# begin getting jaredhanson/connect-ensure-login
# begin getting adafruit/Adafruit-PWM-Servo-Driver-Library
# begin getting invertase/react-native-notifee
# begin getting luyanger1799/Amazing-Semantic-Segmentation
# begin getting ValveSoftware/Dota-2
# begin getting gan74/Yave
# begin getting vuejs/vue-hot-reload-api
# begin getting ierror/ssh-permit-a38
# begin getting camspiers/lens.vim
# begin getting igrigorik/async-rails
# begin getting holman/spaceman-diff
# begin getting yisibl/blog
# begin getting mihaip/readerisdead
# begin getting baseprime/grapnel
# begin getting Deimos/SubredditSimulator
# begin getting jbarnette/johnson
# begin getting chenqihui/NewsFourApp
# begin getting ElemeFE/hire
# begin getting roman01la/webpack-closure-compiler
# begin getting DNFWAH/DNFWAH
# begin getting abinnz/xiaofendui
# begin getting electron-userland/electron-installer-windows
# begin getting ChenglongChen/kaggle-HomeDepot
# begin getting kanaka/wac
# begin getting thma/WhyHaskellMatters
# begin getting emberjs/list-view
# begin getting Polidea/SiriusObfuscator
# begin getting troylelandshields/omgrpc
# begin getting EternalWraith/PalEdit
# begin getting xssc/awesome-slim
# begin getting Earthcomputer/multiconnect
# begin getting Tarsnap/scrypt
# begin getting TencentFemas/femas
# begin getting patrys/httmock
# begin getting stevenjoezhang/bilibili-downloader
# begin getting zerotrac/leetcode_problem_rating
# begin getting debasishg/frdomain
# begin getting mutualmobile/CardStackUI
# begin getting kubernetes-csi/csi-driver-smb
# begin getting WebBreacher/obsidian-osint-templates
# begin getting delfrrr/npm-consider
# begin getting kadirpekel/hammock
# begin getting mrmartineau/SublimeTextSetupWiki
# begin getting exinnet/tclip
# begin getting euvl/vue-js-popover
# begin getting BastiaanJansen/toast-swift

# %%
df1 = pd.read_csv('repo_allbut1.csv')
df2 = pd.read_csv('repos_info_new_topic.csv')
result_df = pd.merge(df1, df2, on='Repository Name', how='left')
result_df.to_csv('repos_info_merge.csv', index=False)

# %%
result_df
# Out:
#                            Repository Name  \
# 0                       hiroi-sora/Umi-OCR
# 1     MostlyAdequate/mostly-adequate-guide
# 2                StreisandEffect/streisand
# 3                              youzan/vant
# 4                          gfwlist/gfwlist
# ...                                    ...
# 3354      mrmartineau/SublimeTextSetupWiki
# 3355                         exinnet/tclip
# 3356                         exinnet/tclip
# 3357                   euvl/vue-js-popover
# 3358            BastiaanJansen/toast-swift
#
#                                             Description  \
# 0     OCR software, free and offline. 开源、免费的离线OCR软件。...
# 1           Mostly adequate guide to FP (in javascript)
# 2     Streisand sets up a new server running your ch...
# 3     A lightweight, customizable Vue UI library for...
# 4                     The one and only one gfwlist here
# ...                                                 ...
# 3354  Enable people to get started with Sublime Text...
# 3355                                             智能图片裁剪
# 3356                                             智能图片裁剪
# 3357  :dango: Vue.js 2 library for dropdowns / popov...
# 3358  Customizable Swift Toast view built with UIKit. 🍞
#
#                                            Code Content  \
# 0     File: .gitignore\nFile: CHANGE_LOG.md\nFile: L...
# 1     File: .editorconfig\nFile: .generate-summary.p...
# 2     File: .gitignore\nFile: Advanced installation....
# 3     File: .browserslistrc\nFile: .editorconfig\nFi...
# 4     File: .gitignore\nFile: COPYING.txt\nFile: REA...
# ...                                                 ...
# 3354  File: README.md\nFile: User/Default (OSX).subl...
# 3355  File: .gitignore\nFile: README.md\nFile: demo_...
# 3356  File: .gitignore\nFile: README.md\nFile: demo_...
# 3357  File: .babelrc\nFile: .gitignore\nFile: .npmig...
# 3358  File: .gitignore\nFile: File.swift\nFile: LICE...
#
#                                          Commit History  \
# 0     Author: hiroi-sora\nDate: 2024-07-19 08:39:10+...
# 1     Author: KtorZ\nDate: 2023-12-08 10:37:50+00:00...
# 2     Author: Patrick Robertson\nDate: 2020-04-12 01...
# 3     Author: inottn\nDate: 2024-07-18 13:56:29+00:0...
# 4     Author: Christopher Meng\nDate: 2024-06-07 03:...
# ...                                                 ...
# 3354  Author: Zander Martineau\nDate: 2015-04-13 05:...
# 3355  Author: exinnet\nDate: 2017-07-03 13:41:17+00:...
# 3356  Author: exinnet\nDate: 2017-07-03 13:41:17+00:...
# 3357  Author: Yev Vlasenko\nDate: 2020-05-10 19:17:0...
# 3358  Author: Bastiaan Jansen\nDate: 2024-02-08 15:1...
#
#                                          README Content  \
# 0     <p align="left">\n    <span>\n        <b>中文</b...
# 1     [![cover](images/cover.png)](SUMMARY.md)\n\n##...
# 2     # Streisand\n\n<p align="center">\n<img src="h...
# 3     <p align="center">\n    <img alt="logo" src="h...
# 4     <a href="http://info.flagcounter.com/T2RV"><im...
# ...                                                 ...
# 3354  # Sublime Text Setup Wiki\n#### This project's...
# 3355  # tclip\r\n\r\n## 名字说明\r\n\r\n* `T`开头，代表是头像识别。...
# 3356  # tclip\r\n\r\n## 名字说明\r\n\r\n* `T`开头，代表是头像识别。...
# 3357  [![npm version](https://badge.fury.io/js/vue-j...
# 3358  # Toast-Swift\n\n[![Codacy Badge](https://app....
#
#                                                    Tags    Topics_x  \
# 0     Tag: v2.1.3.beta.1\nNo additional tag information   paddleocr
# 1           Tag: e5aa315\nNo additional tag information  javascript
# 2                                         No tags found         vpn
# 3            Tag: v4.9.2\nNo additional tag information         vue
# 4                                         No tags found       china
# ...                                                 ...         ...
# 3354                                      No tags found   No topics
# 3355          Tag: 1.0.0\nNo additional tag information   No topics
# 3356          Tag: 1.0.0\nNo additional tag information   No topics
# 3357         Tag: v1.1.8\nNo additional tag information   No topics
# 3358          Tag: 2.1.2\nNo additional tag information       swift
#
#                                                Topics_y
# 0     ['paddleocr', 'ocr', 'ocr-python', 'umi-ocr', ...
# 1     ['javascript', 'functional-programming', 'tuto...
# 2     ['vpn', 'ansible', 'openvpn', 'wireguard', 'op...
# 3     ['vue', 'mobile', 'components', 'vant', 'vue3'...
# 4     ['china', 'censorship-circumvention', 'anticen...
# ...                                                 ...
# 3354                                          No topics
# 3355                                          No topics
# 3356                                          No topics
# 3357                                          No topics
# 3358  ['swift', 'toast', 'toast-notification', 'ios'...
#
# [3359 rows x 8 columns]
