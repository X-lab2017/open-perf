# %%
import pandas as pd
import numpy as np
from clickhouse_driver import Client
import networkx as nx
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# # 读取数据
# npm_packages_df = pd.read_csv('/OpenSource/npm_data/2024-05-13-16-54-33_EXPORT_CSV_13529018_459_0.csv')
# npm_dependencies_df = pd.read_csv('/OpenSource/npm_data/2024-05-13-17-23-22_EXPORT_CSV_13529969_552_0.csv')
# print(npm_packages_df.shape)
# print(npm_dependencies_df.shape)

# %%
# 从clickhouse读取数据
client = Client(host='cc-uf6764sn662413tc9.public.clickhouse.ads.aliyuncs.com',
                user='liangchen',
                password='Liangchen123',
                database='supply_chain')
tables = client.execute('SHOW TABLES')

npm_record_query = 'SELECT * FROM npm_records limit 1000000'
npm_record_result = client.execute(npm_record_query)
npm_dependencies_query = 'SELECT * FROM npm_dependencies limit 1000000'
npm_dependencies_result = client.execute(npm_dependencies_query)

npm_packages_df = pd.DataFrame(npm_record_result, columns=['package_id', 'name', 'version', 'description', 'repository_type', 'repository_url', 'license', 'homepage', 'time'])
npm_dependencies_df = pd.DataFrame(npm_dependencies_result, columns=['package_id', 'dependency_name', 'dependency_verison', 'type'])

# %%
# # 构建一个包id到名称的映射字典
# package_id_to_name = pd.Series(npm_packages_df.name.values, index=npm_packages_df.package_id).to_dict()

# # 创建一个有向图
# G = nx.DiGraph()

# for package_id, package_name in package_id_to_name.items():
#     G.add_node(package_name)

# # 添加边（依赖关系）
# for index, row in npm_dependencies_df.iterrows():
#     package_id = row['package_id']
#     dependency_name = row['dependency_name']

#     if package_id in package_id_to_name.keys():
#         package_name = package_id_to_name[package_id]
#         if dependency_name in package_id_to_name.values():
#             G.add_edge(package_name, dependency_name)

# print("Add edges over.")

# num_edges = G.number_of_edges()
# print("Number of edges:", num_edges)

# isolated_nodes = list(nx.isolates(G))
# G.remove_nodes_from(isolated_nodes)
# num_nodes = G.number_of_nodes()
# print("Number of nodes:", num_nodes)
# Out:
# Add edges over.
# Number of edges: 6180
# Number of nodes: 2709

# %%
############### 并行化 + 持久化 
from concurrent.futures import ProcessPoolExecutor
import json
  
# 假设npm_packages_df和npm_dependencies_df已经加载和定义  
  
# 构建包id到名称的映射  
package_id_to_name = pd.Series(npm_packages_df.name.values, index=npm_packages_df.package_id).to_dict()  
  
# 创建一个有向图  
G = nx.DiGraph()  
  
# 添加所有节点  
for package_id, package_name in package_id_to_name.items():  
    G.add_node(package_name)  
  
# 定义一个函数来并行处理依赖关系  
def add_dependencies(row):  
    package_id = row['package_id']  
    dependency_name = row['dependency_name']  
    if package_id in package_id_to_name and dependency_name in package_id_to_name.values():  
        # 注意：这里我们不直接修改G，而是返回需要添加的边  
        package_name = package_id_to_name[package_id]  
        # 假设dependency_name直接对应一个具体的package_name，这里需要转换  
        # 这可能需要额外的逻辑，因为dependency_name可能不在package_id_to_name的keys中  
        dependency_package_name = next((name for name, id_ in package_id_to_name.items() if name == dependency_name), None)  
        if dependency_package_name:  
            return (package_name, dependency_package_name)  
    return None  
  
# 使用ProcessPoolExecutor并行处理  
edges_to_add = []  
with ProcessPoolExecutor() as executor:  
    future_to_row = {executor.submit(add_dependencies, row): row for index, row in npm_dependencies_df.iterrows()}  
    for future in concurrent.futures.as_completed(future_to_row):  
        edge = future.result()  
        if edge:  
            edges_to_add.append(edge)  
  
# 在主进程中添加边  
for src, dest in edges_to_add:  
    G.add_edge(src, dest)  
  
print("Add edges over.")  

## 持久化...
json_data = nx.readwrite.json_graph.node_link_data(G)
with open('./npm_graph.json', 'w') as file:
    json.dump(json_data, file)

num_edges = G.number_of_edges()  
print("Number of edges:", num_edges)  
  
isolated_nodes = list(nx.isolates(G))  
G.remove_nodes_from(isolated_nodes)  
num_nodes = G.number_of_nodes()  
print("Number of nodes:", num_nodes)

# %%
# 可视化依赖网络
plt.figure(figsize=(12, 12))
pos = nx.spring_layout(G, k=0.1)
nx.draw(G, pos, with_labels=False, node_size=5, font_size=8, node_color='lightblue', edge_color='gray', arrows=True, alpha=0.6)
plt.title('npm Dependency Network')
plt.savefig('./network.svg')
plt.savefig('./network.png')
plt.close()

# %%
# 分析网络
degree_centrality = nx.degree_centrality(G)
clustering_coefficient = nx.clustering(G.to_undirected())
average_path_length = nx.average_shortest_path_length(G) if nx.is_weakly_connected(G) else None
diameter = nx.diameter(G) if nx.is_weakly_connected(G) else None

# %%
print("Degree Centrality: ", degree_centrality)
print("Clustering Coefficient: ", clustering_coefficient)
print("Average Path Length: ", average_path_length)
print("Diameter: ", diameter)
# Out:
# Degree Centrality:  {'0x-hunter-constracts': 0.00036927621861152144, '0x-hunter-core': 0.00036927621861152144, '0x.js': 0.005908419497784343, '0x81-utils': 0.00036927621861152144, '0x81_string': 0.00036927621861152144, '1k-tasks': 0.004062038404726736, '3box': 0.0025849335302806503, '3d-force-graph': 0.0007385524372230429, '3d-force-graph-ar': 0.00036927621861152144, '3d-force-graph-vr': 0.00036927621861152144, '3dio': 0.0014771048744460858, '3h-ast': 0.0011078286558345643, '3h-test': 0.00036927621861152144, '3oilerpl4te': 0.0033234859675036928, '42-cent-base': 0.00036927621861152144, '42-cent-model': 0.00036927621861152144, '42-cent-stripe': 0.0011078286558345643, '42-cent-util': 0.00036927621861152144, '4all-ui': 0.00036927621861152144, 'gulp-ice-builder': 0.00036927621861152144, 'gulp-iconfont': 0.0029542097488921715, 'gulp-if': 0.0018463810930576072, 'gulp-image-resize': 0.00036927621861152144, 'gulp-imagemin': 0.0018463810930576072, 'gulp-include-sources': 0.00036927621861152144, 'gulp-inject': 0.0007385524372230429, 'gulp-inject-envs': 0.00036927621861152144, 'gulp-inject-file': 0.00036927621861152144, 'gulp-inline-css': 0.00036927621861152144, 'gulp-inline-ng2-template': 0.0011078286558345643, 'gulp-install': 0.0007385524372230429, 'gulp-istanbul': 0.0007385524372230429, 'gulp-jade': 0.0014771048744460858, 'gulp-jasmine': 0.0007385524372230429, 'gulp-jest': 0.0007385524372230429, 'gulp-jsbeautifier': 0.00036927621861152144, 'gulp-jscs': 0.0011078286558345643, 'gulp-jscs-stylish': 0.00036927621861152144, 'gulp-jsdoc3': 0.00036927621861152144, 'gulp-jshint': 0.0033234859675036928, 'gulp-json-modify': 0.00036927621861152144, 'gulp-jsonlint': 0.00036927621861152144, 'gulp-jsonminify': 0.00036927621861152144, 'gulp-jspool': 0.00036927621861152144, 'gulp-jsx-coverage': 0.0022156573116691287, 'gulp-less': 0.0022156573116691287, 'gulp-lesshint': 0.00036927621861152144, 'gulp-livereload': 0.00036927621861152144, 'gulp-load-plugins': 0.0036927621861152144, 'gulp-mail': 0.00036927621861152144, 'gulp-mail-builder': 0.0014771048744460858, 'gulp-main-bower-files': 0.0007385524372230429, 'gulp-markdown': 0.00036927621861152144, 'gulp-merge': 0.00036927621861152144, 'gulp-merge-json': 0.00036927621861152144, 'gulp-minify-css': 0.0011078286558345643, 'gulp-minify-html': 0.0014771048744460858, 'gulp-mocha': 0.005539143279172822, 'react-adaptive-list': 0.00036927621861152144, 'react-add-modal': 0.00036927621861152144, 'react-add-to-homescreen': 0.0007385524372230429, 'react-addons-perf': 0.0007385524372230429, 'react-addons-pure-render-mixin': 0.00036927621861152144, 'react-addons-shallow-compare': 0.0007385524372230429, 'react-addons-test-utils': 0.011447562776957165, 'react-addons-update': 0.00036927621861152144, 'react-address-picker-cc-fork': 0.00036927621861152144, 'react-adinkra': 0.0007385524372230429, 'react-admin': 0.00036927621861152144, 'react-admin-component': 0.0018463810930576072, 'react-admin-firebase-jwt2': 0.00036927621861152144, 'react-admin-import-csv': 0.0007385524372230429, 'react-advanced-cropper': 0.00036927621861152144, 'react-affix': 0.00036927621861152144, 'react-agora': 0.0007385524372230429, 'react-alertify-js': 0.0007385524372230429, 'react-algolia': 0.0025849335302806503, 'react-all-progressbar': 0.0018463810930576072, 'react-all-status': 0.00036927621861152144, 'react-alp-route-match-transition': 0.0014771048744460858, 'react-amap': 0.00036927621861152144, 'react-amap-plugin-custom-geolocation': 0.00036927621861152144, 'react-amphora': 0.00036927621861152144, 'react-analog-timer': 0.00036927621861152144, 'react-anchorme': 0.00036927621861152144, 'react-animate-height': 0.00036927621861152144, 'react-animejs': 0.0014771048744460858, 'react-animenu': 0.00036927621861152144, 'react-announce': 0.00036927621861152144, 'react-announce-fetch': 0.00036927621861152144, '@graphql-mesh/transform-mock': 0.0014771048744460858, '@graphql-mesh/transform-naming-convention': 0.0018463810930576072, '@graphql-mesh/transform-pr ...
# Clustering Coefficient:  {'0x-hunter-constracts': 0, '0x-hunter-core': 0, '0x.js': 0.1, '0x81-utils': 0, '0x81_string': 0, '1k-tasks': 0, '3box': 0.14285714285714285, '3d-force-graph': 0, '3d-force-graph-ar': 0, '3d-force-graph-vr': 0, '3dio': 0, '3h-ast': 0, '3h-test': 0, '3oilerpl4te': 0, '42-cent-base': 0, '42-cent-model': 0, '42-cent-stripe': 0, '42-cent-util': 0, '4all-ui': 0, 'gulp-ice-builder': 0, 'gulp-iconfont': 0, 'gulp-if': 0, 'gulp-image-resize': 0, 'gulp-imagemin': 0, 'gulp-include-sources': 0, 'gulp-inject': 0, 'gulp-inject-envs': 0, 'gulp-inject-file': 0, 'gulp-inline-css': 0, 'gulp-inline-ng2-template': 0, 'gulp-install': 0, 'gulp-istanbul': 0, 'gulp-jade': 0, 'gulp-jasmine': 0, 'gulp-jest': 0, 'gulp-jsbeautifier': 0, 'gulp-jscs': 0, 'gulp-jscs-stylish': 0, 'gulp-jsdoc3': 0, 'gulp-jshint': 0.08333333333333333, 'gulp-json-modify': 0, 'gulp-jsonlint': 0, 'gulp-jsonminify': 0, 'gulp-jspool': 0, 'gulp-jsx-coverage': 0.26666666666666666, 'gulp-less': 0, 'gulp-lesshint': 0, 'gulp-livereload': 0, 'gulp-load-plugins': 0, 'gulp-mail': 0, 'gulp-mail-builder': 0, 'gulp-main-bower-files': 0, 'gulp-markdown': 0, 'gulp-merge': 0, 'gulp-merge-json': 0, 'gulp-minify-css': 0, 'gulp-minify-html': 0, 'gulp-mocha': 0.01904761904761905, 'react-adaptive-list': 0, 'react-add-modal': 0, 'react-add-to-homescreen': 0, 'react-addons-perf': 0, 'react-addons-pure-render-mixin': 0, 'react-addons-shallow-compare': 0, 'react-addons-test-utils': 0.008602150537634409, 'react-addons-update': 0, 'react-address-picker-cc-fork': 0, 'react-adinkra': 0, 'react-admin': 0, 'react-admin-component': 0.1, 'react-admin-firebase-jwt2': 0, 'react-admin-import-csv': 0, 'react-advanced-cropper': 0, 'react-affix': 0, 'react-agora': 0, 'react-alertify-js': 0, 'react-algolia': 0, 'react-all-progressbar': 0, 'react-all-status': 0, 'react-alp-route-match-transition': 0.3333333333333333, 'react-amap': 0, 'react-amap-plugin-custom-geolocation': 0, 'react-amphora': 0, 'react-analog-timer': 0, 'react-anchorme': 0, 'react-animate-height': 0, 'react-animejs': 0, 'react-animenu': 0, 'react-announce': 0, 'react-announce-fetch': 0, '@graphql-mesh/transform-mock': 0.6666666666666666, '@graphql-mesh/transform-naming-convention': 0.8, '@graphql-mesh/transform-prefix': 0.8, '@graphql-mesh/transform-prune': 1.0, '@graphql-mesh/transform-rename': 0.8, '@graphql-mesh/transform-snapshot': 0.26666666666666666, '4r-landing-page': 0, '80cents': 0, '8ui': 0, '8x.js': 0, '8x.pay': 0, '@-ui/react': 0, '@-ui/styles': 0, 'react-ant-scheduler': 0.16666666666666666, 'react-any-attr': 0, 'react-apollo': 0, 'react-apollo-decorators': 0, 'react-app-engine': 0.023391812865497075, 'react-app-polyfill': 0, 'react-app-rewire-eslint': 0, 'react-app-rewire-less': 0, 'react-app-rewire-styled-components': 0, 'react-app-rewired': 0, 'react-appinsights': 0, 'react-apple-map': 0, 'react-application-core': 0.16666666666666666, 'react-arc': 0, 'react-area-linkage': 0, 'react-aria-live': 0, 'react-aspect-ratio': 0, 'react-ast': 0, '@radix-ui/react-alert-dialog': 0, '@radix-ui/react-arrow': 0, '@radix-ui/react-aspect-ratio': 0, '@radix-ui/react-avatar': 0, '@radix-ui/react-checkbox': 0, '@radix-ui/react-collapsible': 0.027777777777777776, '@radix-ui/react-compose-refs': 0.3, '@radix-ui/react-context': 0.06666666666666667, '@radix-ui/react-context-menu': 0, '@radix-ui/react-dialog': 0.07575757575757576, '@radix-ui/react-direction': 0, '@radix-ui/react-dismissable-layer': 0.3333333333333333, '@radix-ui/react-dropdown-menu': 0, '@radix-ui/react-focus-guards': 0, '@radix-ui/react-focus-scope': 0, '@radix-ui/react-hover-card': 0, '@radix-ui/react-icons': 0, '@radix-ui/react-id': 0.4, '@radix-ui/react-label': 0, '@radix-ui/react-polymorphic': 0, '@radix-ui/react-popover': 0, '@radix-ui/react-popper': 0.1388888888888889, '@radix-ui/react-portal': 0.6666666666666666, '@radix-ui/react-presence': 0, '@radix-ui/react-primitive': 0.10714285714285714, '@radix-ui/react-progress': 0, '@radix-ui/react-radio-group': 0, '@radi ...
# Average Path Length:  None
# Diameter:  None

# %%
##### 为G做社区发现
import community

# 使用 Louvain 算法进行社区发现
partition = community.best_partition(G)

# 对这个社区发现进行可视化
pos = nx.spring_layout(G)# 创建布局

cmap = plt.cm.get_cmap('viridis', max(partition.values()) + 1)# 绘制节点，根据社区着色
nx.draw_networkx_nodes(G, pos, node_color=list(partition.values()), cmap=cmap, node_size=50, alpha=0.8)

nx.draw_networkx_edges(G, pos, alpha=0.5)# 绘制边
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       2 import community
#       4 # 使用 Louvain 算法进行社区发现
# ----> 5 partition = community.best_partition(G)
#       7 # 对这个社区发现进行可视化
#       8 pos = nx.spring_layout(G)# 创建布局
#
# File d:\Anaconda\envs\graph\lib\site-packages\community\community_louvain.py:249, in best_partition(graph, partition, weight, resolution, randomize, random_state)
#     163 def best_partition(graph,
#     164                    partition=None,
#     165                    weight='weight',
#     166                    resolution=1.,
#     167                    randomize=None,
#     168                    random_state=None):
#     169     """Compute the partition of the graph nodes which maximises the modularity
#     170     (or try..) using the Louvain heuristices
#     171
#    (...)
#     247     >>> plt.show()
#     248     """
# --> 249     dendo = generate_dendrogram(graph,
#     250                                 partition,
#     251                                 weight,
#     252                                 resolution,
#     253                                 randomize,
#     254                                 random_state)
#     255     return partition_at_level(dendo, len(dendo) - 1)
#
# File d:\Anaconda\envs\graph\lib\site-packages\community\community_louvain.py:322, in generate_dendrogram(graph, part_init, weight, resolution, randomize, random_state)
#     264 """Find communities in the graph and return the associated dendrogram
#     265
#     266 A dendrogram is a tree and each level is a partition of the graph nodes.
#    (...)
#     319 :type weight:
#     320 """
#     321 if graph.is_directed():
# --> 322     raise TypeError("Bad graph type, use only non directed graph")
#     324 # Properly handle random state, eventually remove old `randomize` parameter
#     325 # NOTE: when `randomize` is removed, delete code up to random_state = ...
#     326 if randomize is not None:
#
# TypeError: Bad graph type, use only non directed graph
