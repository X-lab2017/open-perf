# %%
import requests
import pandas as pd
from datetime import datetime

# 设置仓库的基本信息
owner = "zhicheng-ning"
repo = "od-api"

# 获取提交信息
def get_commits(owner, repo):
    commits_url = f"https://api.github.com/repos/{owner}/{repo}/commits"
    response = requests.get(commits_url)
    commits = response.json()
    return commits

# 获取Pull Request信息
def get_pull_requests(owner, repo):
    prs_url = f"https://api.github.com/repos/{owner}/{repo}/pulls?state=all"
    response = requests.get(prs_url)
    prs = response.json()
    return prs

# 获取Issue信息
def get_issues(owner, repo):
    issues_url = f"https://api.github.com/repos/{owner}/{repo}/issues?state=all"
    response = requests.get(issues_url)
    issues = response.json()
    return issues

# 处理提交信息
def process_commits(commits):
    commit_data = []
    for commit in commits:
        author = commit['commit']['author']['name']
        date = commit['commit']['author']['date']
        message = commit['commit']['message']
        commit_data.append({
            "author": author,
            "date": date,
            "message": message,
            "type": "code"
        })
    return commit_data

# 处理Pull Request信息
def process_pull_requests(prs):
    pr_data = []
    for pr in prs:
        author = pr['user']['login']
        created_at = pr['created_at']
        merged_at = pr['merged_at']
        pr_data.append({
            "author": author,
            "created_at": created_at,
            "merged_at": merged_at,
            "type": "review"
        })
    return pr_data

# 处理Issue信息
def process_issues(issues):
    issue_data = []
    for issue in issues:
        author = issue['user']['login']
        created_at = issue['created_at']
        closed_at = issue.get('closed_at', None)
        issue_data.append({
            "author": author,
            "created_at": created_at,
            "closed_at": closed_at,
            "type": "discussion"
        })
    return issue_data

# 获取数据
commits = get_commits(owner, repo)
prs = get_pull_requests(owner, repo)
issues = get_issues(owner, repo)

# 处理数据
commit_data = process_commits(commits)
pr_data = process_pull_requests(prs)
issue_data = process_issues(issues)

# 合并数据
collaboration_data = commit_data + pr_data + issue_data

# 打印协作数据
for data in collaboration_data:
    print(data)

## 写入csv
csv_file = 'collaboration_data.csv'
with open(csv_file, mode='w', newline='', encoding='utf-8-sig') as file:
    writer = csv.DictWriter(file, fieldnames=["author", "date", "message", "type", "created_at", "merged_at", "closed_at"])
    writer.writeheader()
    for data in collaboration_data:
        writer.writerow(data)

# 打印统计信息
print(f"\nTotal Commits: {len(commit_data)}")
print(f"Total Pull Requests: {len(pr_data)}")
print(f"Total Issues: {len(issue_data)}")
# Out:
# {'author': 'nzcer', 'date': '2023-12-11T08:39:46Z', 'message': 'fix: add exception handling', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-04-20T11:32:39Z', 'message': 'refactor: fix-thread-executor (#38)', 'type': 'code'}
# {'author': 'andyhuang18', 'date': '2023-04-09T09:19:10Z', 'message': 'ci: support issue comment label (#36)\n\n* add issue workflow v2', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-04-07T14:43:39Z', 'message': 'Update publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate application-dev.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate Dockerfile\n\nUpdate Dockerfile\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\nUpdate Dockerfile\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate publish.yml\n\nUpdate Dockerfile\n\nUpdate application-dev.yml\n\nUpdate application-dev.yml\n\nUpdate publish.yml\n\nrefactor: remove-useless-workflow-code (#33)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-04-07T14:21:33Z', 'message': 'refactor: update-workflow (#31)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-04-07T14:11:03Z', 'message': 'fix: fix-workflow-typo (#30)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-04-07T14:03:47Z', 'message': 'feature: add-workflow (#29)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-04-07T11:55:59Z', 'message': 'refactor: update token and support some log (#28)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-03-18T11:38:02Z', 'message': 'refactor: use ThreadPool to replace creating thread explicitly (#24)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-03-06T06:02:41Z', 'message': 'fix: fix 2021-10 mock data (#22)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-03-04T07:37:23Z', 'message': 'feat: support multi thread (#20)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-02-20T03:16:13Z', 'message': 'docs: add deploy section for readme (#17)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-02-14T12:24:20Z', 'message': 'feat: add github api config and update cron job start time (#13)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-02-07T04:49:36Z', 'message': 'feat: get star and fork from github api (#10)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-01-05T09:29:51Z', 'message': 'chore: update application-dev.yml for  datasource connection-timeout (#8)', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2023-01-05T09:23:37Z', 'message': 'fix: update cron job (#7)\n\n* feat: update NetUtil\r\n\r\n* feat: finish cron job for importing repo data from openleadboard\r\n\r\n* feat: update cron job', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2022-12-26T06:18:48Z', 'message': 'add cron job for importing repo data from openleaderboard (#6)\n\n* feat: update NetUtil\r\n\r\n* feat: finish cron job for importing repo data from openleadboard', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2022-12-07T08:38:16Z', 'message': 'feat: update README (#2)', 'type': 'code'}
# {'author': 'nzcer', 'date': '2022-12-07T07:36:54Z', 'message': 'feat: add more file into .gitignore', 'type': 'code'}
# {'author': 'nzcer', 'date': '2022-12-07T07:26:02Z', 'message': 'feat: add more file into .gitignore', 'type': 'code'}
# {'author': 'nzcer', 'date': '2022-12-07T02:42:55Z', 'message': 'feat: add Dockerfile', 'type': 'code'}
# {'author': 'nzcer', 'date': '2022-12-06T06:47:36Z', 'message': 'feat: add global exception handler and unified return content', 'type': 'code'}
# {'author': 'nzcer', 'date': '2022-12-05T13:59:34Z', 'message': 'feat: sync current version', 'type': 'code'}
# {'author': 'nzcer', 'date': '2022-12-05T13:47:52Z', 'message': 'feat: downgrade jdk and springboot version\n\nadd related dependencies', 'type': 'code'}
# {'author': '逝不等琴生', 'date': '2022-12-01T06:40:15Z', 'message': 'Create README.md', 'type': 'code'}
# {'author': 'nzcer', 'date': '2022-12-01T06:26:14Z', 'message': 'feat: initial commit', 'type': 'code'}
#
# Total Commits: 26
# Total Pull Requests: 0
# Total Issues: 0

# %%
import requests
import pandas as pd
from datetime import datetime

# 设置仓库的基本信息
owner = "leveldb Team"
repo = "leveldb"

# 设置起始和结束日期
start_date = datetime(2019, 1, 1).isoformat()
end_date = datetime(2024, 7, 7).isoformat()

# 获取提交信息
def get_commits(owner, repo, start_date, end_date):
    commits_url = f"https://api.github.com/repos/{owner}/{repo}/commits"
    params = {
        'since': start_date,
        'until': end_date
    }
    response = requests.get(commits_url, params=params)
    commits = response.json()
    return commits

# 获取Pull Request信息
def get_pull_requests(owner, repo, start_date, end_date):
    prs_url = f"https://api.github.com/repos/{owner}/{repo}/pulls?state=all"
    params = {
        'since': start_date,
        'until': end_date
    }
    response = requests.get(prs_url, params=params)
    prs = response.json()
    return prs

# 获取Issue信息
def get_issues(owner, repo, start_date, end_date):
    issues_url = f"https://api.github.com/repos/{owner}/{repo}/issues?state=all"
    params = {
        'since': start_date,
        'until': end_date
    }
    response = requests.get(issues_url, params=params)
    issues = response.json()
    return issues

# 处理提交信息
def process_commits(commits):
    commit_data = []
    for commit in commits:
        author = commit['commit']['author']['name']
        date = commit['commit']['author']['date']
        message = commit['commit']['message']
        commit_data.append({
            "author": author,
            "date": date,
            "message": message,
            "type": "code"
        })
    return commit_data

# 处理Pull Request信息
def process_pull_requests(prs):
    pr_data = []
    for pr in prs:
        author = pr['user']['login']
        created_at = pr['created_at']
        merged_at = pr['merged_at']
        pr_data.append({
            "author": author,
            "created_at": created_at,
            "merged_at": merged_at,
            "type": "review"
        })
    return pr_data

# 处理Issue信息
def process_issues(issues):
    issue_data = []
    for issue in issues:
        author = issue['user']['login']
        created_at = issue['created_at']
        closed_at = issue.get('closed_at', None)
        issue_data.append({
            "author": author,
            "created_at": created_at,
            "closed_at": closed_at,
            "type": "discussion"
        })
    return issue_data

# all_commits = []
# all_prs = []
# all_issues = []
# # 获取数据（定期地）
# while true:
#     commits = get_commits(owner, repo, start_date, end_date)
#     all_commits.extend(commits)
    
#     prs = get_pull_requests(owner, repo, start_date, end_date)
#     all_prs.extend(prs)
    
#     issues = get_issues(owner, repo, start_date, end_date)
#     all_issues.extend(issues)

# 处理数据
commit_data = process_commits(commits)
pr_data = process_pull_requests(prs)
issue_data = process_issues(issues)

# 合并数据
collaboration_data = commit_data + pr_data + issue_data

# 打印协作数据
for data in collaboration_data:
    print(data)

## 写入csv
csv_file = 'collaboration_data2.csv'
with open(csv_file, mode='w', newline='', encoding='utf-8-sig') as file:
    writer = csv.DictWriter(file, fieldnames=["author", "date", "message", "type", "created_at", "merged_at", "closed_at"])
    writer.writeheader()
    for data in collaboration_data:
        writer.writerow(data)

# 打印统计信息
print(f"\nTotal Commits: {len(commit_data)}")
print(f"Total Pull Requests: {len(pr_data)}")
print(f"Total Issues: {len(issue_data)}")
# Out:
# {'author': 'wangyunlai', 'date': '2023-12-25T05:54:11Z', 'message': 'add sysbench liscence (#329)\n\n### What problem were solved in this pull request?\r\n\r\nProblem:\r\nminiob uses sysbench as the concurrency testing tool but there is no\r\nsysbench liscence\r\n\r\n### What is changed and how it works?\r\nadd sysbench liscence', 'type': 'code'}
# {'author': 'Helloworld-lbl', 'date': '2023-12-04T13:21:29Z', 'message': 'Use Ctrl+C to exit observer in cli mode. (#328)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close #281\r\n\r\nProblem: If start observer in cli mode, we cannot exit observer by\r\nCtrl+C.\r\n\r\n### What is changed and how it works?\r\n\r\n    在待输入命令时按下Ctrl+C后，注意到日志中有这样的记录：\r\n"[2023-12-04 11:20:30.830780 pid:5338 tid:7fcf688ee7c0 ctx:0 WARN:\r\nmy_readline@cli_communicator.cpp:71] >> failed to read line: Interrupted\r\nsystem call"\r\n    结合“cli_communicator.cpp:71”代码，可以知道此时系统错误被捕捉到且记录在errno中（此时errno为4）。\r\n\r\n故当fgets读到空字符串时，若errno==4，可判定此时用户按下了Ctrl+C，这与用户输入“exit”等退出命令是等效的，故可看为用户输入了“interrupted"，借用“bool\r\nis_exit_command(const char\r\n*cmd)”函数判断用户输入的命令是否是退出命令，即可实现类似于用户输入了“exit”等命令的退出效果。', 'type': 'code'}
# {'author': 'Wenbin', 'date': '2023-12-01T07:17:12Z', 'message': 'add a lock to make LOG_HEAD thread-safe #{317} (#327)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close #317 \r\n\r\nProblem:\r\nlocaltime is not a thread-safe function.\r\n\r\n### What is changed and how it works?\r\nuse localtime_r instead of localtime\r\n\r\n\r\nCo-authored-by: Helloworld-lbl <114924425+Helloworld-lbl@users.noreply.github.com>\r\nCo-authored-by: wangyunlai <hnwyllmm@126.com>', 'type': 'code'}
# {'author': 'Helloworld-lbl', 'date': '2023-12-01T02:20:29Z', 'message': 'Issue Number: close #255 (#326)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close #255\r\n\r\nProblem: 将 https://ask.oceanbase.com/t/topic/35604437/8 中的内容写入到\r\nhow_to_build.md 的FAQ章节中\r\n\r\n### What is changed and how it works?\r\n\r\n### Other information', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-11-29T02:47:10Z', 'message': 'Codecov (#324)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close #172\r\n\r\nProblem:\r\n增加单元测试统计信息', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-11-28T12:46:09Z', 'message': 'Asan (#323)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: \r\nclose #253 \r\nclose #254 \r\n\r\nProblem:\r\n参考libzmq，利用sanity工具帮助代码更健壮', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-11-22T05:49:00Z', 'message': 'use latest libevent (#321)\n\nuse the latest libevent', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-11-17T08:18:12Z', 'message': 'Clang format (#320)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close #260\r\n\r\nclang-format', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-11-15T02:00:29Z', 'message': 'clang-format (#319)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: ref #260 \r\n\r\nclang-format', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-11-14T09:30:05Z', 'message': 'clang-format (#318)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: ref #260 \r\n\r\ncode format\r\n\r\nformat command:\r\n```\r\nclang-format --Werror --sort-includes -i src/observer/common/types.h\r\n```', 'type': 'code'}
# {'author': 'Fischer', 'date': '2023-11-08T12:33:25Z', 'message': 'fix:修复了mvcc模式下无法正确删除由当前事务插入的记录 (#315)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close #314 \r\nmvcc模式下无法正确删除当前事务插入的记录\r\n\r\n\r\n### What is changed and how it works?\r\n\r\n在trx.delete_record添加特判，如果是删除当前事务插入的记录，就直接调用delete_record,并且也不添加到operation_里面，同时清除operation里面的相关insert_operation,这样可以保证事务内、提交后、回滚后、都能正确执行，并且不影响垃圾回收', 'type': 'code'}
# {'author': 'Fischer', 'date': '2023-11-07T12:35:48Z', 'message': 'fix:修复了set_schema当中会因为多次调用open而添加重复数据的问题 (#313)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close #311 \r\n\r\n\r\nProblem:NLJ里面会遍历多次右表，就会调用很多次open，在open当中就会调用set_schema，然后join的时候就会添加大量重复的field和value的tuple，后续的话会被select的字段给过滤掉，不影响正确性，但是进行了冗余存储\r\n\r\n### What is changed and how it works?\r\n在set_schema当中，每次先将原本的数据clear掉\r\n\r\n### Other information', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-11-07T11:32:00Z', 'message': '修复sql_debug没有发送消息终结符的问题 (#298)\n\n### What problem were solved in this pull request?\r\n\r\nProblem:\r\nsql-debug的消息没有发送最终的消息终结符，并且消息是在消息终结符发送后发送的。\r\n\r\n### What is changed and how it works?\r\n消息终结符统一在write_result最后发送，其它函数不再发送', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-11-03T10:18:40Z', 'message': 'add contributors (#310)\n\n### What is changed and how it works?\r\nadd contributors graph', 'type': 'code'}
# {'author': 'my0sotis', 'date': '2023-10-27T01:31:03Z', 'message': 'fix: overflow (#309)\n\n### What problems were solved in this pull request?\r\n\r\nProblem: `compare_int` uses subtraction to determine the size of two\r\nintegers, which may cause integer overflow and return incorrect results.\r\n\r\n### How to reproduce\r\n\r\nWhen v1 is -2147483648 and v2 is 1, return 2147483647. Returned\r\nincorrect result due to integer overflow\r\n\r\n### What is changed and how it works?\r\n\r\nUse comparison operators instead of subtraction.', 'type': 'code'}
# {'author': 'Steve Lee', 'date': '2023-10-20T15:39:39Z', 'message': 'fix: do not close in ExplainPhysicalOperator (#300)\n\n### What problem were solved in this pull request?\r\n\r\nProblem: do not close child operator in ExplainPhysicalOperator\r\n\r\n### How to reproduce:\r\n\r\n```\r\ncreate table a (a int);\r\ncreate index idx on a(a);\r\nexplain delete from a where a=1;\r\n```\r\n\r\ncause SegFault, because trying to close IndexScanPhysicalOperator, but\r\nnot open\r\n\r\n### What is changed and how it works?\r\n\r\nJust do not close child oper in `ExplainPhysicalOperator::close`', 'type': 'code'}
# {'author': 'Double', 'date': '2023-10-20T08:54:28Z', 'message': 'bugfix: fix get record failed when page_handler has inited (#292)\n\n### What problem were solved in this pull request?\r\n\r\nIn the `next()` function of Operator,\r\n`record_handler_->get_record(record_page_handler_, &rid, readonly_,\r\n&current_record_)` may be invoked more than one time. In this case,\r\n`record_page_handler_` has inited, it will return `RC::RECORD_OPENNED`,\r\nand `get_record()` will be failed.\r\n\r\n### What is changed and how it works?\r\nIf the page_handler is inited, then reinit it if need otherwise return RECORD_OPENNED.', 'type': 'code'}
# {'author': '漠中洲', 'date': '2023-10-17T10:40:53Z', 'message': '补充文档辅助零基础者在windows上使用docker和vscode配置环境 (#295)\n\n### What problem were solved in this pull request?\r\n\r\nProblem:增添了辅助配置环境的文档 以及文档附属图片\r\n\r\n### What is changed and how it works?\r\n\r\n新增了一个教学文档，辅助零基础者在windows上使用docker和vscode配置环境', 'type': 'code'}
# {'author': 'ggb', 'date': '2023-10-16T02:20:35Z', 'message': 'snprintf函数第二个参数应该为buf_len + 1 (#290)\n\n### What problem were solved in this pull request?\r\n计算程序名称时，snprintf函数第二个参数应该为buf_len + 1', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-10-10T09:21:42Z', 'message': '增加调试信息页面 (#284)\n\n### What problem were solved in this pull request?\r\n\r\nProblem:\r\n有训练营自助调试的页面，但是主页上没有展示\r\n\r\n### What is changed and how it works?\r\n在summary.md中增加链接', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-10-08T10:58:27Z', 'message': '忽略不能识别的命令行参数 (#282)\n\n### What problem were solved in this pull request?\r\n\r\nProblem:\r\n当前observer如果收到多余的命令行参数，进程会直接退出。如果训练营改版依赖某些参数，会导致启动参数不兼容\r\n\r\n### What is changed and how it works?\r\n遇到不能识别的参数直接忽略', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-10-07T02:43:06Z', 'message': 'launsh.json增加cppdbg (#280)\n\n### What problem were solved in this pull request?\r\n\r\nProblem:\r\nlldb 调试配置不能在某些linux平台中运行\r\n\r\n### What is changed and how it works?\r\n增加cppdbg和lldb两种调试配置', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-09-27T09:37:00Z', 'message': 'Blog (#277)\n\n### What problem were solved in this pull request?\r\n\r\nProblem:\r\ngitbook compile failed\r\n\r\n### What is changed and how it works?\r\nfix summary.md: add an introduction.md in blog and add a link in\r\nsummary.md', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-09-27T08:43:11Z', 'message': 'Blog (#275)\n\n### What is changed and how it works?\r\n1. 增加了一个MVCC的博客\r\n2. 增加github训练营使用说明', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-09-25T01:30:10Z', 'message': '修复basic-2022测试失败的问题 (#269)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close #267 \r\n\r\nProblem:\r\n训练营2022 basic测试用例失败。\r\n\r\n### What is changed and how it works?\r\n1. 经过测试发现，创建索引时，B+树的第一个页面（存放元数据的页面）数据都是空的，导致重启时没有相关数据，初始化mem_pool失败；\r\n2. table_meta的拷贝复制函数没有复制table_id字段，导致在创建索引时，丢失了table_id字段', 'type': 'code'}
# {'author': 'Peng LinFeng', 'date': '2023-09-19T02:49:41Z', 'message': 'fix shutdown database without sync index file header (#271)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close #270 \r\n\r\nProblem: When the database is shut down, the index file header does not\r\nsync properly.\r\n\r\n### What is changed and how it works?\r\nWhen the database is shut down，check header_dirty_ flag in\r\nBplusTreeHandler, if true, sync the index file.\r\n\r\n---------\r\n\r\nCo-authored-by: wangyunlai <hnwyllmm@126.com>', 'type': 'code'}
# {'author': 'wangyunlai', 'date': '2023-09-13T12:08:12Z', 'message': 'Create codeql.yml (#265)\n\n### What problem were solved in this pull request?\r\n\r\nProblem:\r\nadd code quality scan.', 'type': 'code'}
# {'author': 'YunShu', 'date': '2023-09-13T07:04:24Z', 'message': 'fix: delete sql_event after use (#261)\n\n### What problem were solved in this pull request?\r\n\r\nProblem: memory leak\r\n---------\r\n\r\nCo-authored-by: wangyunlai <hnwyllmm@126.com>', 'type': 'code'}
# {'author': 'YunShu', 'date': '2023-09-06T08:03:55Z', 'message': 'style: add a rule to avoid formatting LOG_* macros (#259)\n\n### What problem were solved in this pull request?\r\n\r\nIssue Number: close https://github.com/oceanbase/miniob/issues/258\r\n\r\n日志中的参数直接使用clang-format格式化，参数要么在一行，要么一个一行，或者尽量在一行，会比较丑。主要是因为日志的参数第一个format string，通常比较长，并且其含义特殊，参数需要分多行时，不应该作为“一类”放在同一行上。', 'type': 'code'}
# {'author': 'YunShu', 'date': '2023-09-05T01:31:05Z', 'message': 'fix: add missing header files (#257)\n\nmy gcc version:\r\n\r\n```text\r\ngcc 版本 13.2.1 20230801 (GCC)\r\n```\r\n\r\nbuild log:\r\n```log\r\n[ 69%] Building CXX object src/observer/CMakeFiles/observer_static.dir/storage/trx/trx.cpp.o\r\nIn file included from /home/yunshu/Studio/GitHub/miniob/src/observer/storage/persist/persist.cpp:18:\r\n/home/yunshu/Studio/GitHub/miniob/src/observer/storage/persist/persist.h:48:15: 错误：‘uint64_t’未声明\r\n   48 |   RC write_at(uint64_t offset, int size, const char *data, int64_t *out_size = nullptr);\r\n      |               ^~~~~~~~\r\n```\r\n\r\n### What problem were solved in this pull request?\r\n\r\nProblem: build failed because the declaration of uint64_t could not be\r\nfound.\r\n\r\n### What is changed and how it works?\r\n\r\nadd `<stdint.h>`', 'type': 'code'}
# {'author': 'hnwyllmm', 'created_at': '2024-05-11T09:33:00Z', 'merged_at': '2024-05-11T09:35:35Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-04-22T03:37:56Z', 'merged_at': '2024-04-22T03:38:46Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-04-18T07:53:06Z', 'merged_at': '2024-04-18T07:53:21Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-04-17T10:19:15Z', 'merged_at': '2024-04-18T06:26:41Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-04-15T08:42:41Z', 'merged_at': '2024-04-15T08:44:04Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-03-20T07:52:00Z', 'merged_at': '2024-03-20T09:28:01Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-03-12T13:15:25Z', 'merged_at': '2024-03-12T13:20:51Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-02-27T10:19:00Z', 'merged_at': '2024-02-28T02:47:49Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-02-04T06:48:42Z', 'merged_at': '2024-02-05T02:04:43Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-02-01T13:19:52Z', 'merged_at': '2024-02-02T01:47:21Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2023-08-23T07:47:04Z', 'merged_at': '2023-08-23T07:47:19Z', 'type': 'review'}
# {'author': 'hnwyllmm', 'created_at': '2024-05-11T09:33:00Z', 'closed_at': '2024-05-11T09:35:35Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2024-04-22T03:37:56Z', 'closed_at': '2024-04-22T03:38:46Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2024-04-18T07:53:06Z', 'closed_at': '2024-04-18T07:53:21Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2024-04-17T10:19:15Z', 'closed_at': '2024-04-18T06:26:41Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2024-04-15T08:42:41Z', 'closed_at': '2024-04-15T08:44:05Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2024-03-20T07:52:00Z', 'closed_at': '2024-03-20T09:28:01Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2024-03-12T13:15:25Z', 'closed_at': '2024-03-12T13:20:51Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2024-02-27T10:19:00Z', 'closed_at': '2024-02-28T02:47:49Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2024-02-04T06:48:42Z', 'closed_at': '2024-02-05T02:04:43Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2024-02-01T13:19:52Z', 'closed_at': '2024-02-02T01:47:21Z', 'type': 'discussion'}
# {'author': 'hnwyllmm', 'created_at': '2023-08-23T07:47:04Z', 'closed_at': '2023-08-23T07:47:19Z', 'type': 'discussion'}
#
# Total Commits: 30
# Total Pull Requests: 11
# Total Issues: 11
